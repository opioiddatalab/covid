// %% [markdown]
// I am doing this analysis because...

// %%
// Importing data
sysuse lifeexp.dta, clear
// Out:
// (Life expectancy, 1998)

// %%
summarize
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       region |         68         1.5    .7431277          1          3
//      country |          0
//    popgrowth |         68    .9720588    .9311918        -.5          3
//         lexp |         68    72.27941    4.715315         54         79
//        gnppc |         63    8674.857    10634.68        370      39980
// -------------+---------------------------------------------------------
//    safewater |         40        76.1    17.89112         28        100

// %%
hist safewater, bin(10)
// Out:
// (bin=10, start=28, width=7.2)
// This front-end cannot display the desired image type.

// %%
graph two fpfitci lexp safewater || scatter lexp safewater
// Out:
// This front-end cannot display the desired image type.

// %%
graph
