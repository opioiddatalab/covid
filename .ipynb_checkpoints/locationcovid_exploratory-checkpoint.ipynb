// %% [markdown]
// <font size=7> Social distancing: evidence of privilege in a pandemic from smartphones </font><br>
// Nabarun Dasgupta, MPH, PhD | nab@unc.edu | @nabarund<br>
// *Dr. Dasgupta is an epidemiologist at the University of North Carolina in Chapel Hill. He studies population level patterns of infectious disease, medication safety, and opioids.*<br>
// Thanks to Ben White for data munging help. Code available on [GitHub](https://github.com/opioiddatalab/covid).

// %%
display "Notebook generated on $S_DATE at $S_TIME ET"
// Out:
// Notebook generated on 15 Apr 2020 at 23:59:27 ET

// %% [markdown]
// On March 23, 2020 Stuart Thompson and Yaryna Serkez of *The New York Times* [published](https://www.nytimes.com/interactive/2020/03/23/opinion/coronavirus-economy-recession.html) a fascinating use of cell phone GPS signal information to gauge movement and commuting, during the advent of social distancing. They compared the state-level data in a [slick graphic](https://www.nytimes.com/interactive/2020/03/23/opinion/coronavirus-economy-recession.html) to political leanings. But we wanted to understand more about other community level characteristics of slow versus fast adopters.<br>
// <br>
// We were provided access to the same location dataset on social distancing published today in the. We used a data merging approach we have [previously published](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6339867/). Repurposing code from an ongoing project, we merged in community-level data from the Robert Wood Johnson Foundation's [County Health Rankings](https://www.countyhealthrankings.org/). This very rich dataset contains dozens of explanatory variables about health, social, and economic indicators.<br>

// %%
// Load pre-procesed data
clear all
set scheme economist
use "https://github.com/opioiddatalab/covid/blob/master/analysiset.dta?raw=true"

// Basic distributions of 
tab rucc, m
tab iso5, m
table iso5, c(sum last3_sample)
format last3_sample %13.0fc
su last3_sample
di "Total 3-day mobile traces: " r(sum)

// Set up reporting output programs 
program define pdiff
    version 16
    qui: lincom (levels5-levels1), ef
    local d=r(estimate)
    local se=r(se)
    di "Percent difference (high-low): " round(((`d'-1)*100),.1) "% (95% CI: " round((((`d'-1)*100)-(1.96*`se')),.1) "%, " round((((`d'-1)*100)+(1.96*`se')),.1) "%)"
end

// Create results frame
frame create results str20 strat level avg LL UL

// Set up program for main models
program define modelrun, rclass
    version 16
    syntax varlist(numeric)
    
    frame change default
    foreach var of local varlist {
    * Tabular
        qui: tabulate iso5, generate(levels)
        *table iso5, c(count pcp_rate mean pcp_rate sem pcp_rate) 
    * Base model
        glm `var' levels*, family(poisson) link(log) scale(x2) nocons eform 
    * Rurality-adjusted model
        glm `var' levels* i.rucc, family(poisson) link(log) scale(x2) eform nocons
        
    * Store results
        frame post results ("`var'") (1) (round((r(table)[1,1]),.1)) (round((r(table)[5,1]),.1)) (round((r(table)[6,1]),.1))
        frame post results ("`var'") (2) (round((r(table)[1,2]),.1)) (round((r(table)[5,2]),.1)) (round((r(table)[6,2]),.1))
        frame post results ("`var'") (3) (round((r(table)[1,3]),.1)) (round((r(table)[5,3]),.1)) (round((r(table)[6,3]),.1))
        frame post results ("`var'") (4) (round((r(table)[1,4]),.1)) (round((r(table)[5,4]),.1)) (round((r(table)[6,4]),.1))
        frame post results ("`var'") (5) (round((r(table)[1,5]),.1)) (round((r(table)[5,5]),.1)) (round((r(table)[6,5]),.1))

   * Percent difference between highest and lowest mobility tiers
        pdiff
        drop levels*

        glm `var' iso5 i.rucc, family(poisson) link(log) scale(x2) eform nocons


   * Plot graph
       frame change results
       la var level "Social Distancing: Lowest (1) to Highest (5)"
       line avg level if inlist(strat,"`var'")
    frame change default
    }
end
// Out:
//   RUCC_2013 |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        348       16.42       16.42
//           2 |        297       14.01       30.42
//           3 |        272       12.83       43.25
//           4 |        164        7.74       50.99
//           5 |         81        3.82       54.81
//           6 |        445       20.99       75.80
//           7 |        316       14.91       90.71
//           8 |         98        4.62       95.33
//           9 |         99        4.67      100.00
// ------------+-----------------------------------
//       Total |      2,120      100.00
//
//
// Distancing: |
//  Lowest (1) |
//  to Highest |
//         (5) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        413       19.48       19.48
//           2 |        428       20.19       39.67
//           3 |        424       20.00       59.67
//           4 |        430       20.28       79.95
//           5 |        425       20.05      100.00
// ------------+-----------------------------------
//       Total |      2,120      100.00
//
//
// -------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       | sum(last3_~e)
// ----------+--------------
//         1 |       1010551
//         2 |       1529483
//         3 |       2311589
//         4 |       2466153
//         5 |       5826931
// -------------------------
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// last3_sample |      2,120    6200.333    14197.24        101     267893
//
// Total 3-day mobile traces: 13144707

// %% [markdown]
// ---
// # Primary Care Providers
//
// We wanted to see if places with more social distancing had better healthcare resources. So we looked at primary care providers per 100,000 population.

// %%
// Comparing Primary Care Physicians per 100,000 population to social distancing
modelrun pcp_rate
// Out:
// note: pcp_rate has noninteger values
//
// Iteration 0:   log likelihood = -23331.854
// Iteration 1:   log likelihood = -23233.099
// Iteration 2:   log likelihood = -23233.051
// Iteration 3:   log likelihood = -23233.051
//
// Generalized linear models                         Number of obs   =      2,076
// Optimization     : ML                             Residual df     =      2,071
//                                                   Scale parameter =          1
// Deviance         =   34634.0426                   (1/df) Deviance =   16.72334
// Pearson          =  37880.80066                   (1/df) Pearson  =   18.29107
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   22.38733
// Log likelihood   = -23233.05141                   BIC             =   18815.33
//
// ------------------------------------------------------------------------------
//              |                 OIM
//     pcp_rate |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   50.11318   1.519498   129.09   0.000     47.22178    53.18161
//      levels2 |   49.06581   1.461788   130.68   0.000     46.28281    52.01617
//      levels3 |   55.24894   1.562361   141.87   0.000     52.27008    58.39756
//      levels4 |   56.14298   1.556268   145.31   0.000     53.17413    59.27759
//      levels5 |   71.06645   1.757158   172.44   0.000      67.7046    74.59523
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// note: pcp_rate has noninteger values
//
// Iteration 0:   log likelihood = -21612.412
// Iteration 1:   log likelihood = -21504.677
// Iteration 2:   log likelihood = -21504.606
// Iteration 3:   log likelihood = -21504.606
//
// Generalized linear models                         Number of obs   =      2,076
// Optimization     : ML                             Residual df     =      2,063
//                                                   Scale parameter =          1
// Deviance         =   31177.1518                   (1/df) Deviance =   15.11253
// Pearson          =  33834.06692                   (1/df) Pearson  =   16.40042
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   20.72987
// Log likelihood   = -21504.60602                   BIC             =   15419.55
//
// ------------------------------------------------------------------------------
//              |                 OIM
//     pcp_rate |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   51.23458   2.154797    93.60   0.000     47.18064    55.63686
//      levels2 |   50.02746   2.016296    97.08   0.000     46.22765    54.13961
//      levels3 |   57.64853   2.185708   106.93   0.000     53.51992    62.09562
//      levels4 |   58.11508   2.120763   111.32   0.000     54.10362    62.42395
//      levels5 |   72.44149   2.280784   136.03   0.000     68.10637    77.05255
//              |
//         rucc |
//           2  |   1.053876   .0433411     1.28   0.202     .9722626    1.142341
//           3  |   1.162945   .0488609     3.59   0.000     1.071016    1.262764
//           4  |   .9396443   .0481149    -1.22   0.224     .8499186    1.038842
//           5  |   1.326339   .0816436     4.59   0.000     1.175597    1.496411
//           6  |   .8136188   .0330993    -5.07   0.000     .7512643    .8811487
//           7  |    1.05379   .0444338     1.24   0.214     .9702027    1.144578
//           8  |   .5874758   .0466712    -6.70   0.000     .5027679    .6864557
//           9  |   .6552897   .0504792    -5.49   0.000      .563459    .7620867
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Percent difference (high-low): 41.4% (95% CI: 41.3%, 41.5%)
// This front-end cannot display the desired image type.

// %% [markdown]
// Graph above: Comparing **Primary Care Physicians** per 100,000 population to social distancing

// %% [markdown]
// ---
//
// # Mental Health Providers
//
// For people sequestered at home, mental health providers may play an emerging role. These data are from CMS National Provider Identification (NPI) via [RWJF](https://www.countyhealthrankings.org/explore-health-rankings/measures-data-sources/2020-measures). It is expressed in rates per 100,000 population.

// %%
// Comparing mental health provider rate to social distancing
modelrun mhproviders_rate
// Out:
// note: mhproviders_rate has noninteger values
//
// Iteration 0:   log likelihood = -135255.68
// Iteration 1:   log likelihood =    -133462
// Iteration 2:   log likelihood = -133457.61
// Iteration 3:   log likelihood = -133457.61
//
// Generalized linear models                         Number of obs   =      2,064
// Optimization     : ML                             Residual df     =      2,059
//                                                   Scale parameter =          1
// Deviance         =  253610.5557                   (1/df) Deviance =   123.1717
// Pearson          =     334687.3                   (1/df) Pearson  =   162.5485
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   129.3242
// Log likelihood   =  -133457.607                   BIC             =   237895.4
//
// -------------------------------------------------------------------------------
//               |                 OIM
// mhproviders~e |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
//       levels1 |   146.1647   7.835329    92.99   0.000      131.587    162.3574
//       levels2 |   140.8855   7.401784    94.18   0.000     127.1002    156.1659
//       levels3 |   142.3221   7.439427    94.85   0.000     128.4631    157.6762
//       levels4 |   151.1992   7.640559    99.31   0.000     136.9417    166.9411
//       levels5 |   220.9864   9.248038   128.99   0.000     203.5841    239.8764
// -------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// note: mhproviders_rate has noninteger values
//
// Iteration 0:   log likelihood = -125758.66
// Iteration 1:   log likelihood = -123720.27
// Iteration 2:   log likelihood = -123713.46
// Iteration 3:   log likelihood = -123713.46
//
// Generalized linear models                         Number of obs   =      2,064
// Optimization     : ML                             Residual df     =      2,051
//                                                   Scale parameter =          1
// Deviance         =  234122.2588                   (1/df) Deviance =   114.1503
// Pearson          =  320494.6514                   (1/df) Pearson  =   156.2626
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =     119.89
// Log likelihood   = -123713.4585                   BIC             =   218468.2
//
// -------------------------------------------------------------------------------
//               |                 OIM
// mhproviders~e |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
//       levels1 |    140.286   10.86041    63.86   0.000     120.5362    163.2718
//       levels2 |    138.356   10.23183    66.66   0.000     119.6876    159.9362
//       levels3 |   144.3339   10.32812    69.48   0.000     125.4465    166.0649
//       levels4 |   151.3042   10.33327    73.49   0.000     132.3484    172.9751
//       levels5 |    217.046   12.33369    94.68   0.000       194.17    242.6172
//               |
//          rucc |
//            2  |   1.150851   .0859164     1.88   0.060     .9941984    1.332188
//            3  |   1.158869   .0906057     1.89   0.059      .994222    1.350781
//            4  |   1.099721   .0991738     1.05   0.292     .9215528    1.312334
//            5  |   1.604052   .1717597     4.41   0.000     1.300388    1.978627
//            6  |    .746799    .058177    -3.75   0.000     .6410525    .8699893
//            7  |   1.210722   .0918271     2.52   0.012     1.043483    1.404766
//            8  |   .4803374   .0777878    -4.53   0.000     .3497031    .6597712
//            9  |    .610721   .0893184    -3.37   0.001     .4585154    .8134516
// -------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Percent difference (high-low): 54.7% (95% CI: 54.5%, 54.9%)
// This front-end cannot display the desired image type.

// %% [markdown]
// Graph above: Comparing **mental health provider rate per 100k** to social distancing

// %% [markdown]
// ---
// # Health Insurance
//
// Getting hospitalized for Covid-19 is sure to be expensive. After hearing that even some front line nurses in pulmonary infectious disease units in North Carolina do not have health insurance, we wanted to see if there was any association between health insurance status and social distancing.

// %%
// Comparing percent uninsured to social distancing
modelrun uninsured_p
// Out:
// note: uninsured_p has noninteger values
//
// Iteration 0:   log likelihood = -6390.8478
// Iteration 1:   log likelihood = -6384.0951
// Iteration 2:   log likelihood = -6384.0941
// Iteration 3:   log likelihood = -6384.0941
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,115
//                                                   Scale parameter =          1
// Deviance         =  3948.525685                   (1/df) Deviance =   1.866915
// Pearson          =  4144.546207                   (1/df) Pearson  =   1.959596
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   6.027447
// Log likelihood   = -6384.094076                   BIC             =  -12250.62
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  uninsured_p |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   12.78995   .2463444   132.32   0.000     12.31613    13.28201
//      levels2 |   12.39957   .2382675   131.02   0.000     11.94126    12.87547
//      levels3 |   11.20078   .2275226   118.94   0.000      10.7636    11.65571
//      levels4 |   10.56832   .2194583   113.55   0.000     10.14682    11.00732
//      levels5 |   8.351614   .1962339    90.33   0.000     7.975724    8.745219
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// note: uninsured_p has noninteger values
//
// Iteration 0:   log likelihood = -6346.1374
// Iteration 1:   log likelihood = -6339.2591
// Iteration 2:   log likelihood =  -6339.258
// Iteration 3:   log likelihood =  -6339.258
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =  3858.853452                   (1/df) Deviance =   1.831444
// Pearson          =  4034.666486                   (1/df) Pearson  =   1.914887
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.992696
// Log likelihood   = -6339.257959                   BIC             =  -12279.02
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  uninsured_p |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   11.54411   .3716519    75.98   0.000     10.83819    12.29601
//      levels2 |   11.31721   .3525158    77.89   0.000     10.64696    12.02965
//      levels3 |   10.24367   .3159986    75.42   0.000     9.642672    10.88212
//      levels4 |   9.736128   .2945156    75.24   0.000     9.175667    10.33082
//      levels5 |   7.839302   .2332184    69.22   0.000     7.395273    8.309991
//              |
//         rucc |
//           2  |   1.044691   .0366437     1.25   0.213     .9752838    1.119038
//           3  |   1.027965    .037031     0.77   0.444     .9578889    1.103168
//           4  |   1.065743   .0440024     1.54   0.123      .982897    1.155571
//           5  |   1.044578   .0553567     0.82   0.411     .9415252     1.15891
//           6  |   1.181122   .0371326     5.29   0.000     1.110541     1.25619
//           7  |   1.127842    .038606     3.51   0.000     1.054658    1.206104
//           8  |   1.178599   .0558575     3.47   0.001     1.074052    1.293324
//           9  |   1.160372   .0551012     3.13   0.002     1.057249    1.273554
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Percent difference (high-low): -32.1% (95% CI: -32.1%, -32.1%)
// This front-end cannot display the desired image type.

// %% [markdown]
// Graph above: Comparing **percent uninsured** to social distancing
//
// Alarmingly, counties with lower social distancing also had more uninsured residents!

// %% [markdown]
// ---
// # Flu Vaccination
//
// We had a hypothesis that counties that were more involved in preventative behaviors would be more likely to self-isolate more thoroughly. To test this, we examined whether earlier flu vaccination rates impacted how much the county was likely to slow down in the current coronavirus outbreak. This is quantified as the percent of annual Medicare enrollees having an annual flu vaccination, as reported by the Robert Wood Johnson Foundation. Since the flu vaccine is free to all Medicare beneficiaries, and this is the elderly age group with the most influenza mortality, this is a convenient metric to test *a priori* how conscientious the population was, on average.

// %%
// Basic descriptive on background influenza vaccine
frame change default
summ fluvaccine, d
hist fluvaccine, bin(10)
// Out:
//         % Medicare Beneficiaries Getting Flu Vaccine
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%           18              9
//  5%           25              9
// 10%           30             12       Obs               2,117
// 25%           37             12       Sum of Wgt.       2,117
//
// 50%           43                      Mean           41.94898
//                         Largest       Std. Dev.      8.715751
// 75%           48             62
// 90%           52             62       Variance       75.96431
// 95%           54             63       Skewness      -.6494537
// 99%           57             65       Kurtosis       3.299656
//
// (bin=10, start=9, width=5.6)
// This front-end cannot display the desired image type.

// %%
// Comparing background flu vaccination with current social distancing
modelrun fluvaccine
// Out:
// Iteration 0:   log likelihood = -7905.7721
// Iteration 1:   log likelihood = -7904.3973
// Iteration 2:   log likelihood = -7904.3973
//
// Generalized linear models                         Number of obs   =      2,117
// Optimization     : ML                             Residual df     =      2,112
//                                                   Scale parameter =          1
// Deviance         =  4054.140934                   (1/df) Deviance =   1.919574
// Pearson          =  3762.128022                   (1/df) Pearson  =   1.781311
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =    7.47227
// Log likelihood   = -7904.397299                   BIC             =  -12119.04
//
// ------------------------------------------------------------------------------
//              |                 OIM
//   fluvaccine |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   40.60097   .4194857   358.48   0.000     39.78707    41.43153
//      levels2 |   41.02804   .4132266   368.78   0.000     40.22607    41.84599
//      levels3 |   42.43868   .4222482   376.70   0.000     41.61911    43.27439
//      levels4 |   41.55116   .4148845   373.26   0.000     40.74591    42.37233
//      levels5 |   44.09906    .430429   387.93   0.000     43.26345     44.9508
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
//
// Iteration 0:   log likelihood = -7631.6118
// Iteration 1:   log likelihood = -7630.0075
// Iteration 2:   log likelihood = -7630.0075
//
// Generalized linear models                         Number of obs   =      2,117
// Optimization     : ML                             Residual df     =      2,104
//                                                   Scale parameter =          1
// Deviance         =  3505.361375                   (1/df) Deviance =   1.666046
// Pearson          =    3327.5039                   (1/df) Pearson  =   1.581513
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   7.220602
// Log likelihood   = -7630.007519                   BIC             =  -12606.56
//
// ------------------------------------------------------------------------------
//              |                 OIM
//   fluvaccine |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   45.26564   .6626964   260.42   0.000     43.98523    46.58331
//      levels2 |   44.56386   .6236329   271.32   0.000     43.35817    45.80308
//      levels3 |   45.92847   .6178907   284.47   0.000     44.73325    47.15562
//      levels4 |   44.64784   .5838011   290.52   0.000     43.51815    45.80686
//      levels5 |   46.53079    .550833   324.39   0.000      45.4636    47.62302
//              |
//         rucc |
//           2  |   .9869411   .0147357    -0.88   0.379     .9584782    1.016249
//           3  |   .9996201   .0153995    -0.02   0.980     .9698887    1.030263
//           4  |    .972152   .0174815    -1.57   0.116     .9384857    1.007026
//           5  |   .9394379   .0227645    -2.58   0.010     .8958633     .985132
//           6  |   .8707038   .0123261    -9.78   0.000     .8468771    .8952009
//           7  |   .8310896   .0131051   -11.73   0.000     .8057969    .8571763
//           8  |   .8439141   .0194537    -7.36   0.000      .806634    .8829171
//           9  |   .7855351   .0187123   -10.13   0.000     .7497026    .8230802
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Percent difference (high-low): 2.8% (95% CI: 2.8%, 2.8%)
// This front-end cannot display the desired image type.

// %% [markdown]
// Grpah above: Comparing background **flu vaccination** with current social distancing

// %% [markdown]
// ---
// # Income
//
// There is a trend emerging. So, since the places with more social distancing seem to have more health resources, perhaps there are trends in financial means? Income data are from the American Community Survey 5-year estimates via [RWJF](https://www.countyhealthrankings.org/explore-health-rankings/measures-data-sources/2020-measures).

// %%
// Comparing 80th percentile income to social distancing
modelrun income80
// Out:
// Iteration 0:   log likelihood = -4584134.2
// Iteration 1:   log likelihood = -4577940.3
// Iteration 2:   log likelihood = -4577940.1
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,115
//                                                   Scale parameter =          1
// Deviance         =   9127704.57                   (1/df) Deviance =     4315.7
// Pearson          =  9699170.043                   (1/df) Pearson  =   4585.896
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   4318.816
// Log likelihood   = -4577940.112                   BIC             =    9111505
//
// ------------------------------------------------------------------------------
//              |                 OIM
//     income80 |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   87235.42   984.2003  1008.35   0.000      85327.6    89185.91
//      levels2 |   89858.22   981.2262  1044.53   0.000     87955.49    91802.12
//      levels3 |   95620.92   1016.964  1078.30   0.000     93648.34    97635.05
//      levels4 |   97679.65   1020.657  1099.57   0.000     95699.54    99700.72
//      levels5 |   111823.8   1098.461  1183.40   0.000     109691.4    113997.6
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
//
// Iteration 0:   log likelihood = -3152263.6
// Iteration 1:   log likelihood = -3145304.1
// Iteration 2:   log likelihood = -3145303.8
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =  6262431.899                   (1/df) Deviance =   2972.203
// Pearson          =  6507503.606                   (1/df) Pearson  =   3088.516
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =    2967.28
// Log likelihood   = -3145303.776                   BIC             =    6246294
//
// ------------------------------------------------------------------------------
//              |                 OIM
//     income80 |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   113768.8   1504.022   880.63   0.000     110858.8    116755.2
//      levels2 |   114233.8   1431.822   929.14   0.000     111461.7    117074.9
//      levels3 |   120014.8   1431.824   980.30   0.000       117241    122854.2
//      levels4 |   120616.5   1380.671  1022.15   0.000     117940.6    123353.2
//      levels5 |   132115.6   1330.899  1170.51   0.000     129532.7      134750
//              |
//         rucc |
//           2  |   .8405282   .0111948   -13.04   0.000     .8188706    .8627585
//           3  |   .8135721   .0113933   -14.73   0.000     .7915453    .8362118
//           4  |   .7573612   .0127202   -16.55   0.000      .732836    .7827072
//           5  |   .8086028   .0180498    -9.52   0.000     .7739886    .8447651
//           6  |   .7196894   .0091449   -25.89   0.000     .7019871    .7378381
//           7  |   .7403905    .010371   -21.46   0.000     .7203401     .760999
//           8  |   .6931949   .0148711   -17.08   0.000     .6646523    .7229632
//           9  |   .6902289   .0148865   -17.19   0.000       .66166    .7200314
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Percent difference (high-low): 16.1% (95% CI: 16.1%, 16.2%)
// This front-end cannot display the desired image type.

// %% [markdown]
// Graph above: Comparing **80th percentile income** to social distancing

// %% [markdown]
// ---
// # Income Inequality
//
// So places with more social distancing tend to be wealthier. What about income inequality? Is this merely a matter of have and have-nots? Or does the overall structure of society tell us something. There are many compelling ways to measure income inequality. We are using the ratio of the 80th percentile of income to the 20th percentile. Loosely interpreted, the closer to 4.0, the less inequality there is. Income data are from the American Community Survey 5-year estimates via [RWJF](https://www.countyhealthrankings.org/explore-health-rankings/measures-data-sources/2020-measures).

// %%
// Comparing income inequality to social distancing
modelrun incomeratio
// Out:
// note: incomeratio has noninteger values
//
// Iteration 0:   log likelihood = -3695.2801
// Iteration 1:   log likelihood = -3695.2346
// Iteration 2:   log likelihood = -3695.2346
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,115
//                                                   Scale parameter =          1
// Deviance         =  225.5008231                   (1/df) Deviance =   .1066198
// Pearson          =  235.1617731                   (1/df) Pearson  =   .1111876
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   3.490787
// Log likelihood   = -3695.234588                   BIC             =  -15973.65
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  incomeratio |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   4.732531   .0356944   206.10   0.000     4.663086     4.80301
//      levels2 |   4.624906   .0346623   204.34   0.000     4.557466    4.693345
//      levels3 |    4.48479   .0342939   196.25   0.000     4.418077    4.552511
//      levels4 |   4.474691   .0340154   197.12   0.000     4.408516    4.541859
//      levels5 |   4.459901   .0341583   195.21   0.000     4.393452    4.527355
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// note: incomeratio has noninteger values
//
// Iteration 0:   log likelihood = -3694.5753
// Iteration 1:   log likelihood =  -3694.528
// Iteration 2:   log likelihood =  -3694.528
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =  224.0876637                   (1/df) Deviance =   .1063539
// Pearson          =   233.675438                   (1/df) Pearson  =   .1109043
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   3.497668
// Log likelihood   = -3694.528009                   BIC             =  -15913.79
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  incomeratio |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   4.633379   .0551699   128.77   0.000       4.5265    4.742782
//      levels2 |   4.534093   .0520977   131.56   0.000     4.433124    4.637361
//      levels3 |   4.398819   .0493943   131.92   0.000     4.303066    4.496703
//      levels4 |   4.394993   .0477905   136.15   0.000     4.302316    4.489666
//      levels5 |   4.393737   .0439829   147.86   0.000     4.308373    4.480793
//              |
//         rucc |
//           2  |   1.018709   .0127781     1.48   0.139     .9939698    1.044064
//           3  |   1.021754   .0132113     1.66   0.096     .9961861    1.047979
//           4  |   1.035497   .0154181     2.34   0.019     1.005715    1.066161
//           5  |    1.04533   .0203453     2.28   0.023     1.006205    1.085977
//           6  |   1.025728   .0118383     2.20   0.028     1.002786    1.049195
//           7  |    1.00551   .0127053     0.43   0.664     .9809141    1.030723
//           8  |   1.023887   .0184655     1.31   0.191     .9883273    1.060726
//           9  |   1.034308   .0185854     1.88   0.060     .9985151    1.071384
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Percent difference (high-low): -5.2% (95% CI: -5.2%, -5.2%)
// This front-end cannot display the desired image type.

// %% [markdown]
// ---
//
// # Exploratory analyses

// %%
frame change default
foreach var of varlist drivealone_p {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (mean) `var', by(iso5)
                    la var `var' "% of Drivers"
                        line `var' iso5, note("Commuting Alone by Vehicle")  
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(drivea~p)  mean(drivea~p)   sem(drivea~p)
// ----------+-----------------------------------------------
//         1 |            413       81.487109        .2927337
//         2 |            428       82.139165        .2155603
//         3 |            424       81.411898        .2187233
//         4 |            430       80.398328        .2396714
//         5 |            425       77.242536        .4385472
// ----------------------------------------------------------
// This front-end cannot display the desired image type.

// %% [markdown]
// ---

// %%
frame change default
foreach var of varlist rucc {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (median) `var', by(iso5)
                    la var `var' "Meidan RUCC"
                        line `var' iso5, note("Urban-Rural")   
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(rucc)  mean(rucc)   sem(rucc)
// ----------+-----------------------------------
//         1 |        413   5.4576273    .1075586
//         2 |        428   4.6214952    .1109247
//         3 |        424   4.4221697    .1194589
//         4 |        430   4.1744184    .1205308
//         5 |        425   3.4682353    .1208512
// ----------------------------------------------
// This front-end cannot display the desired image type.

// %%
frame change default
foreach var of varlist longcommute_p {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (mean) `var', by(iso5)
                    la var `var' "% of Solo Commuters Driving 30+ mins"
                        line `var' iso5, note("Long Solo Commute")     
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(longco~p)  mean(longco~p)   sem(longco~p)
// ----------+-----------------------------------------------
//         1 |            413       27.315981        .6152999
//         2 |            428       30.938551        .5943382
//         3 |            424       32.049057        .6043237
//         4 |            430       32.656512        .5600595
//         5 |            425            33.8         .561355
// ----------------------------------------------------------
// This front-end cannot display the desired image type.

// %% [markdown]
// ---
// # Google location context
