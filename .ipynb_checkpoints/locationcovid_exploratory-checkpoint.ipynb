// %% [markdown]
// <font size=5> Social distancing: evidence of privilege in a pandemic from smartphones </font><br>
// Nabarun Dasgupta, MPH, PhD | nab@unc.edu | @nabarund<br>
// *Dr. Dasgupta is an epidemiologist at the University of North Carolina in Chapel Hill. He studies population level patterns of infectious disease, medication safety, and opioids.*<br>
// Thanks to Ben White for data munging help. Code available on [GitHub](https://github.com/opioiddatalab/covid).<br>
//
// **Co-authors**<br>
// Michele Jonsson Funk, PhD<br>
// Allison Lazard, PhD<br>
// Benjamin Eugene White<br>
// Steve W. Marshall, PhD<br>

// %% [markdown]
// <div class="alert alert-warning">
//
// **Warning:** Code and output provided for evaluation only. Paper under review. Results have not been peer-reviewed and should not be used for clinical or public health interpretation.
//
// </div>

// %% [markdown]
// On March 23, 2020 Stuart Thompson and Yaryna Serkez of *The New York Times* [published](https://www.nytimes.com/interactive/2020/03/23/opinion/coronavirus-economy-recession.html) a fascinating use of cell phone GPS signal information to gauge movement and commuting, during the advent of social distancing. They compared the state-level data in a [slick graphic](https://www.nytimes.com/interactive/2020/03/23/opinion/coronavirus-economy-recession.html) to political leanings. But we wanted to understand more about other community level characteristics of slow versus fast adopters.<br>
// <br>
// We were provided access to the same location dataset on social distancing published today in the. We used a data merging approach we have [previously published](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6339867/). Repurposing code from an ongoing project, we merged in community-level data from the Robert Wood Johnson Foundation's [County Health Rankings](https://www.countyhealthrankings.org/). This very rich dataset contains dozens of explanatory variables about health, social, and economic indicators.<br>
//
// ---

// %%
display "Notebook generated on $S_DATE at $S_TIME ET"
// Out:
// Notebook generated on 21 Apr 2020 at 22:28:13 ET

// %% [markdown]
// # Models

// %%
// Load pre-procesed data
clear all
set scheme economist
use "https://github.com/opioiddatalab/covid/blob/master/analysiset.dta?raw=true"

// Create results frame
frame create results str20 strat level avg LL UL

// Program to invert differences
program define invert, rclass
    version 16
    args ee ll ul
    
    di round((1-(1/`ee'))*-100,.1)
    di "LL: " round((1-(1/`ll'))*-100,.1)
    di "UL: " round((1-(1/`ul'))*-100,.1)
end

// Set up negative binomial model
program define modelrun, rclass
    version 16
    syntax varlist(numeric)
    
    frame change default
    foreach var of local varlist {
    
    di "----- RURALITY-ADJUSTED NEGBIN MODEL -----"
       nbreg `var' levels* homeorder i.rucc, irr nocons vce(r)

    * Store results
        frame post results ("`var'") (1) (round((r(table)[1,1]),.1)) (round((r(table)[5,1]),.1)) (round((r(table)[6,1]),.1))
        frame post results ("`var'") (2) (round((r(table)[1,2]),.1)) (round((r(table)[5,2]),.1)) (round((r(table)[6,2]),.1))
        frame post results ("`var'") (3) (round((r(table)[1,3]),.1)) (round((r(table)[5,3]),.1)) (round((r(table)[6,3]),.1))
        frame post results ("`var'") (4) (round((r(table)[1,4]),.1)) (round((r(table)[5,4]),.1)) (round((r(table)[6,4]),.1))
        frame post results ("`var'") (5) (round((r(table)[1,5]),.1)) (round((r(table)[5,5]),.1)) (round((r(table)[6,5]),.1))
        
        di "Compare to tabular data:"
        table iso5, c(count `var' mean `var' sem `var') 

    di "----- PERCENT DIFFERENCE MODEL -----"
    * Rate difference models
        nbreg `var' levels* homeorder i.rucc, irr vce(r)   
           
   * Plot graph
       frame change results
       la var level "Social Distancing: Lowest (1) to Highest (5)"
       line avg level if inlist(strat,"`var'"), title("`var'")

    frame change default
    
    }
end

// Set up scaled Poisson model

program define modelpoisson, rclass
    version 16
    syntax varlist(numeric)
    
    frame change default
    foreach var of local varlist {

    di "----- RURALITY-ADJUSTED POISSON MODEL -----"
       glm `var' levels* homeorder i.rucc, family(poisson) link(log) scale(x2) eform nocons 

    * Store results
        frame post results ("`var'") (1) (round((r(table)[1,1]),.1)) (round((r(table)[5,1]),.1)) (round((r(table)[6,1]),.1))
        frame post results ("`var'") (2) (round((r(table)[1,2]),.1)) (round((r(table)[5,2]),.1)) (round((r(table)[6,2]),.1))
        frame post results ("`var'") (3) (round((r(table)[1,3]),.1)) (round((r(table)[5,3]),.1)) (round((r(table)[6,3]),.1))
        frame post results ("`var'") (4) (round((r(table)[1,4]),.1)) (round((r(table)[5,4]),.1)) (round((r(table)[6,4]),.1))
        frame post results ("`var'") (5) (round((r(table)[1,5]),.1)) (round((r(table)[5,5]),.1)) (round((r(table)[6,5]),.1))
        
        di "Compare to tabular data:"
        table iso5, c(count `var' mean `var' sem `var') 

    di "----- PERCENT DIFFERENCE MODEL -----"
    * Rate difference models
       glm `var' levels* homeorder i.rucc, family(poisson) link(log) scale(x2) eform 
           
   * Plot graph
       frame change results
       la var level "Social Distancing: Lowest (1) to Highest (5)"
       line avg level if inlist(strat,"`var'"), title("`var'")

    frame change default
    
    }
end

// %% [markdown]
// ---
//
// # Descriptive Results

// %%
// Basic distributions of counties and traces
* iso5 is the main outcome variable representing quintiles of mobility change

tab rucc, m
tab iso5, m
table iso5, c(sum last3_sample)
su last3_sample
di "Total 3-day mobile traces: " r(sum)

* US average change in mobility
qui: su last3_index
    return list

* Mean mobility change by quintile
table iso5, c(count last3_index mean last3_index sem last3_index sum samples) 

* Mean mobility change by status of homeorder
table homeorder, c(mean last3_index sem last3_index)

* Rurality/urbanicity by quintile
table iso5, c(median rucc)
// Out:
//        rucc |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        345       16.27       16.27
//           2 |        309       14.58       30.85
//           3 |        273       12.88       43.73
//           4 |        171        8.07       51.79
//           5 |         76        3.58       55.38
//           6 |        436       20.57       75.94
//           7 |        322       15.19       91.13
//           8 |         94        4.43       95.57
//           9 |         94        4.43      100.00
// ------------+-----------------------------------
//       Total |      2,120      100.00
//
//
// Distancing: |
//  Lowest (1) |
//  to Highest |
//         (5) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        421       19.86       19.86
//           2 |        422       19.91       39.76
//           3 |        423       19.95       59.72
//           4 |        429       20.24       79.95
//           5 |        425       20.05      100.00
// ------------+-----------------------------------
//       Total |      2,120      100.00
//
//
// -------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       | sum(last3_~e)
// ----------+--------------
//         1 |        997370
//         2 |       1442412
//         3 |       2242183
//         4 |       2907797
//         5 |       5823421
// -------------------------
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// last3_sample |      2,120    6326.973    14928.19        101     285845
//
// Total 3-day mobile traces: 13413183
//
//
//
// scalars:
//                   r(N) =  2120
//               r(sum_w) =  2120
//                r(mean) =  42.10385226161694
//                 r(Var) =  556.9398589649319
//                  r(sd) =  23.59957327929748
//                 r(min) =  0
//                 r(max) =  378.3333435058594
//                 r(sum) =  89260.1667946279
//
//
// --------------------------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(last3_~x)  mean(last3_~x)   sem(last3_~x)    sum(samples)
// ----------+---------------------------------------------------------------
//         1 |            421        72.94656        1.062045        1.75e+07
//         2 |            422        54.61612         .165701        2.47e+07
//         3 |            423        42.55398        .1587755        3.76e+07
//         4 |            429        29.90132        .2108481        4.97e+07
//         5 |            425        10.99686        .3446614        9.74e+07
// --------------------------------------------------------------------------
//
//
// ----------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |  med(rucc)
// ----------+-----------
//         1 |          6
//         2 |          5
//         3 |          4
//         4 |          3
//         5 |          3
// ----------------------

// %% [markdown]
// ---
// # Healthcare
//
// To gauge overall baseline healthcare access and utilization, we examined primary care providers per 100,000 population and percent uninsured under age 65 (e.g., Medicare eligibility). As a marker for a closely related preventive health behavior, we examined whether earlier influenza vaccination rates were associated with how much the county was likely to slow down in the current coronavirus outbreak. This was quantified as the percent of annual Medicare enrollees having an annual influenza vaccination.
//
// ## Primary care providers
//
// We wanted to see if places with more social distancing had better healthcare resources. So we looked at primary care providers per 100,000 population.

// %%
modelrun pcp_rate
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood =  -262062.8
// Iteration 1:   log pseudolikelihood = -38731.813
// Iteration 2:   log pseudolikelihood = -24586.661
// Iteration 3:   log pseudolikelihood = -21454.969
// Iteration 4:   log pseudolikelihood = -21454.025
// Iteration 5:   log pseudolikelihood = -21454.025
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -10387.184
// Iteration 1:   log pseudolikelihood = -9930.2182
// Iteration 2:   log pseudolikelihood = -9722.2536
// Iteration 3:   log pseudolikelihood = -9721.8562
// Iteration 4:   log pseudolikelihood = -9721.8561
//
// Negative binomial regression                    Number of obs     =      2,070
// Dispersion           = mean                     Wald chi2(14)     =  127578.87
// Log pseudolikelihood = -9721.8561               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//     pcp_rate |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   49.86183   2.485431    78.43   0.000     45.22087    54.97908
//      levels2 |   51.47449     2.5724    78.86   0.000     46.67172    56.77148
//      levels3 |   57.77577    2.87086    81.64   0.000      52.4143    63.68566
//      levels4 |   62.38172   2.936121    87.82   0.000     56.88449     68.4102
//      levels5 |   72.97482   3.567173    87.76   0.000     66.30777    80.31223
//    homeorder |   .9757942   .0314245    -0.76   0.447     .9161069     1.03937
//              |
//         rucc |
//           2  |   1.038127   .0431851     0.90   0.368      .956844    1.126314
//           3  |   1.150164   .0590027     2.73   0.006     1.040144    1.271821
//           4  |   .9643965    .043044    -0.81   0.417     .8836167    1.052561
//           5  |   1.317121   .0690389     5.25   0.000     1.188526     1.45963
//           6  |   .8181835   .0337712    -4.86   0.000     .7545997     .887125
//           7  |   1.061389    .046653     1.36   0.175     .9737786    1.156881
//           8  |    .608444   .0503656    -6.00   0.000      .517321    .7156177
//           9  |   .6656759   .0476989    -5.68   0.000     .5784557    .7660474
// -------------+----------------------------------------------------------------
//     /lnalpha |  -1.348491   .0389672                     -1.424865   -1.272116
// -------------+----------------------------------------------------------------
//        alpha |   .2596318   .0101171                      .2405409    .2802379
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(pcp_rate)  mean(pcp_rate)   sem(pcp_rate)
// ----------+-----------------------------------------------
//         1 |            401       46.994226        1.277088
//         2 |            414       49.673068        1.399466
//         3 |            413        55.05037        1.591743
//         4 |            420       59.571005        1.445676
//         5 |            422        70.23037        2.095071
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -21454.052
// Iteration 1:   log pseudolikelihood = -21454.025
// Iteration 2:   log pseudolikelihood = -21454.025
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -10436.407
// Iteration 1:   log pseudolikelihood = -10024.565
// Iteration 2:   log pseudolikelihood = -9888.8868
// Iteration 3:   log pseudolikelihood = -9888.8332
// Iteration 4:   log pseudolikelihood = -9888.8332
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -9736.0168
// Iteration 1:   log pseudolikelihood = -9721.9952
// Iteration 2:   log pseudolikelihood = -9721.8561
// Iteration 3:   log pseudolikelihood = -9721.8561
//
// Negative binomial regression                    Number of obs     =      2,070
//                                                 Wald chi2(13)     =     341.24
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -9721.8561               Pseudo R2         =     0.0169
//
// ------------------------------------------------------------------------------
//              |               Robust
//     pcp_rate |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .6832744   .0281883    -9.23   0.000     .6302009    .7408176
//      levels2 |   .7053733   .0286882    -8.58   0.000     .6513281    .7639029
//      levels3 |    .791722   .0322862    -5.73   0.000      .730905    .8575994
//      levels4 |    .854839   .0321824    -4.17   0.000     .7940335    .9203009
//      levels5 |          1  (omitted)
//    homeorder |   .9757942   .0314245    -0.76   0.447     .9161069     1.03937
//              |
//         rucc |
//           2  |   1.038127   .0431851     0.90   0.368     .9568439    1.126314
//           3  |   1.150164   .0590027     2.73   0.006     1.040144     1.27182
//           4  |   .9643964   .0430439    -0.81   0.417     .8836166    1.052561
//           5  |   1.317121   .0690389     5.25   0.000     1.188526     1.45963
//           6  |   .8181834   .0337712    -4.86   0.000     .7545996    .8871249
//           7  |   1.061389    .046653     1.36   0.175     .9737785    1.156881
//           8  |    .608444   .0503656    -6.00   0.000      .517321    .7156177
//           9  |   .6656759   .0476989    -5.68   0.000     .5784557    .7660473
//              |
//        _cons |   72.97483   3.567173    87.76   0.000     66.30777    80.31223
// -------------+----------------------------------------------------------------
//     /lnalpha |  -1.348491   .0389672                     -1.424865   -1.272116
// -------------+----------------------------------------------------------------
//        alpha |   .2596318   .0101171                      .2405409    .2802379
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |    49.4269   2.469613    78.06   0.000       44.816    54.51219
//      levels2 |   50.90777   2.527614    79.15   0.000     46.18715    56.11086
//      levels3 |   56.66436   2.832643    80.76   0.000      51.3758    62.49733
//      levels4 |   62.54773   2.997007    86.32   0.000     56.94109    68.70642
//      levels5 |   72.75614   3.547062    87.94   0.000     66.12584    80.05124
// `
// <br><br>
// Percent difference<br>
// `levels1 |   .6793503    .027583    -9.52   0.000     .6273836    .7356213`

// %%
invert .6793503 .6273836 .7356213
// Out:
// 47.2
// LL: 59.4
// UL: 35.9

// %% [markdown]
// The lowest social distancing counties had 49.4 primary care providers per 100,000, whereas the most social distancing counties had 72.7 per 100,000 after adjusting for rurality and social distancing orders, a 47% (95% CI: 36%, 59%) difference.
//
// ---

// %% [markdown]
// ## Percent uninsured
// Percent of without health insurance below Medicare elgibility (age 65).

// %%
// Comparing percent uninsured to social distancing
modelpoisson uninsured_p
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
// note: uninsured_p has noninteger values
//
// Iteration 0:   log likelihood =   -6310.57
// Iteration 1:   log likelihood = -6303.5204
// Iteration 2:   log likelihood = -6303.5192
// Iteration 3:   log likelihood = -6303.5192
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,106
//                                                   Scale parameter =          1
// Deviance         =  3795.460534                   (1/df) Deviance =   1.802213
// Pearson          =  3978.200337                   (1/df) Pearson  =   1.888984
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.959924
// Log likelihood   = -6303.519212                   BIC             =  -12334.75
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  uninsured_p |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   10.95993   .4467071    58.74   0.000     10.11846    11.87138
//      levels2 |   10.34383   .4193072    57.64   0.000     9.553807    11.19919
//      levels3 |   9.262221   .3772976    54.64   0.000     8.551481    10.03203
//      levels4 |   8.337182   .3374153    52.40   0.000     7.701409     9.02544
//      levels5 |   7.099623   .2911682    47.79   0.000     6.551277    7.693865
//    homeorder |    1.12976   .0314206     4.39   0.000     1.069826    1.193053
//              |
//         rucc |
//           2  |   1.021081   .0354173     0.60   0.548     .9539713    1.092911
//           3  |   1.014946   .0363401     0.41   0.679     .9461628     1.08873
//           4  |   1.065679   .0430204     1.58   0.115     .9846101    1.153423
//           5  |   1.023821    .055715     0.43   0.665     .9202436    1.139057
//           6  |    1.16839   .0368176     4.94   0.000     1.098412    1.242826
//           7  |   1.117526   .0384738     3.23   0.001     1.044606    1.195536
//           8  |   1.176135    .055958     3.41   0.001     1.071417    1.291087
//           9  |   1.125007   .0547918     2.42   0.016     1.022583    1.237689
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(uninsu~p)  mean(uninsu~p)   sem(uninsu~p)
// ----------+-----------------------------------------------
//         1 |            421       13.292438        .2315588
//         2 |            422       12.409833        .2303796
//         3 |            423       11.110163        .2413227
//         4 |            429       9.9419569         .215415
//         5 |            425       8.4250426        .1994217
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
// note: uninsured_p has noninteger values
//
// Iteration 0:   log likelihood =   -6310.57
// Iteration 1:   log likelihood = -6303.5204
// Iteration 2:   log likelihood = -6303.5192
// Iteration 3:   log likelihood = -6303.5192
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,106
//                                                   Scale parameter =          1
// Deviance         =  3795.460534                   (1/df) Deviance =   1.802213
// Pearson          =  3978.200337                   (1/df) Pearson  =   1.888984
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.959924
// Log likelihood   = -6303.519212                   BIC             =  -12334.75
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  uninsured_p |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.543734    .047561    14.09   0.000     1.453275    1.639824
//      levels2 |   1.456955   .0446048    12.29   0.000     1.372103    1.547055
//      levels3 |   1.304607   .0403699     8.59   0.000     1.227835     1.38618
//      levels4 |   1.174313   .0368484     5.12   0.000     1.104268    1.248802
//      levels5 |          1  (omitted)
//    homeorder |    1.12976   .0314206     4.39   0.000     1.069826    1.193053
//              |
//         rucc |
//           2  |   1.021081   .0354173     0.60   0.548     .9539713    1.092911
//           3  |   1.014946   .0363401     0.41   0.679     .9461628     1.08873
//           4  |   1.065679   .0430204     1.58   0.115     .9846101    1.153423
//           5  |   1.023821    .055715     0.43   0.665     .9202436    1.139057
//           6  |    1.16839   .0368176     4.94   0.000     1.098412    1.242826
//           7  |   1.117526   .0384738     3.23   0.001     1.044606    1.195536
//           8  |   1.176135    .055958     3.41   0.001     1.071417    1.291087
//           9  |   1.125007   .0547918     2.42   0.016     1.022583    1.237689
//              |
//        _cons |   7.099623   .2911682    47.79   0.000     6.551277    7.693865
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   11.31834   .4589692    59.84   0.000      10.4536    12.25462
//      levels2 |   10.65563    .429903    58.65   0.000      9.84549    11.53244
//      levels3 |   9.304829   .3793602    54.71   0.000     8.590228    10.07888
//      levels4 |   8.544709   .3466857    52.88   0.000     7.891533    9.251949
//      levels5 |   7.267551   .2956462    48.76   0.000     6.710594    7.870734
// `
// <br><br>
// Percent difference<br>
// `levels1 |   1.557381    .047272    14.59   0.000     1.467431    1.652844`
//
// Counties with lower social distancing also had a higher proportion of people without health insurance. The lowest social distancing counties had 11.3% uninsured adults, whereas the most social distancing counties had only 7.27% uninsured after adjusting for rurality and social distancing orders, a 56% (95% CI: 47%, 65%) difference.
//
// ---

// %% [markdown]
// ## Flu Vaccination
//
// We had a hypothesis that counties that were more involved in preventative behaviors would be more likely to self-isolate more thoroughly. To test this, we examined whether earlier flu vaccination rates impacted how much the county was likely to slow down in the current coronavirus outbreak. This is quantified as the percent of annual Medicare enrollees having an annual flu vaccination, as reported by the Robert Wood Johnson Foundation. Since the flu vaccine is free to all Medicare beneficiaries, and this is the elderly age group with the most influenza mortality, this is a convenient metric to test *a priori* how conscientious the population was, on average.

// %%
// Basic descriptive on background influenza vaccine
frame change default
summ fluvaccine, d
hist fluvaccine, bin(10)
// Out:
//         % Medicare Beneficiaries Getting Flu Vaccine
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%           18              9
//  5%           26              9
// 10%           30             12       Obs               2,117
// 25%           37             12       Sum of Wgt.       2,117
//
// 50%           43                      Mean           42.01984
//                         Largest       Std. Dev.      8.651113
// 75%           48             62
// 90%           52             62       Variance       74.84176
// 95%           54             63       Skewness       -.636839
// 99%           57             65       Kurtosis       3.259204
//
// (bin=10, start=9, width=5.6)
// This front-end cannot display the desired image type.

// %%
// Comparing background flu vaccination with current social distancing
modelpoisson fluvaccine
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
//
// Iteration 0:   log likelihood = -7562.6785
// Iteration 1:   log likelihood = -7561.1127
// Iteration 2:   log likelihood = -7561.1127
//
// Generalized linear models                         Number of obs   =      2,117
// Optimization     : ML                             Residual df     =      2,103
//                                                   Scale parameter =          1
// Deviance         =  3362.719437                   (1/df) Deviance =   1.599011
// Pearson          =  3187.028718                   (1/df) Pearson  =   1.515468
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =    7.15646
// Log likelihood   = -7561.112669                   BIC             =  -12741.54
//
// ------------------------------------------------------------------------------
//              |                 OIM
//   fluvaccine |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   47.96233   .8779733   211.43   0.000     46.27204    49.71437
//      levels2 |   48.10962   .8626035   216.03   0.000     46.44831    49.83035
//      levels3 |   48.58313   .8682443   217.29   0.000     46.91086    50.31501
//      levels4 |   49.54674   .8660889   223.28   0.000     47.87798    51.27365
//      levels5 |   50.76849   .8782014   227.03   0.000     49.07609    52.51924
//    homeorder |   .9158932   .0114801    -7.01   0.000     .8936667    .9386724
//              |
//         rucc |
//           2  |     .98957    .014373    -0.72   0.470     .9617967    1.018145
//           3  |    .999568   .0151122    -0.03   0.977     .9703831    1.029631
//           4  |   .9801939   .0170053    -1.15   0.249     .9474243    1.014097
//           5  |   .9342681    .022715    -2.80   0.005     .8907916    .9798666
//           6  |   .8750012   .0122831    -9.51   0.000     .8512549    .8994099
//           7  |   .8231018   .0128865   -12.43   0.000     .7982283    .8487504
//           8  |   .8373453   .0194117    -7.66   0.000     .8001504    .8762691
//           9  |   .7887648   .0188638    -9.92   0.000     .7526455    .8266173
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(fluvac~e)  mean(fluvac~e)   sem(fluvac~e)
// ----------+-----------------------------------------------
//         1 |            419       39.954655        .4099078
//         2 |            422       41.279621        .4230407
//         3 |            423       41.600471        .4288632
//         4 |            428       42.948597        .4161437
//         5 |            425       44.272942        .3944843
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
//
// Iteration 0:   log likelihood = -7562.6785
// Iteration 1:   log likelihood = -7561.1127
// Iteration 2:   log likelihood = -7561.1127
//
// Generalized linear models                         Number of obs   =      2,117
// Optimization     : ML                             Residual df     =      2,103
//                                                   Scale parameter =          1
// Deviance         =  3362.719437                   (1/df) Deviance =   1.599011
// Pearson          =  3187.028718                   (1/df) Pearson  =   1.515468
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =    7.15646
// Log likelihood   = -7561.112669                   BIC             =  -12741.54
//
// ------------------------------------------------------------------------------
//              |                 OIM
//   fluvaccine |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .9447264   .0130117    -4.13   0.000      .919565    .9705763
//      levels2 |   .9476276   .0126543    -4.03   0.000     .9231474     .972757
//      levels3 |   .9569545   .0125708    -3.35   0.001     .9326307    .9819128
//      levels4 |   .9759349    .012577    -1.89   0.059     .9515931    1.000899
//      levels5 |          1  (omitted)
//    homeorder |   .9158932   .0114801    -7.01   0.000     .8936667    .9386724
//              |
//         rucc |
//           2  |     .98957    .014373    -0.72   0.470     .9617967    1.018145
//           3  |    .999568   .0151122    -0.03   0.977     .9703831    1.029631
//           4  |   .9801939   .0170053    -1.15   0.249     .9474243    1.014097
//           5  |   .9342681    .022715    -2.80   0.005     .8907916    .9798666
//           6  |   .8750012   .0122831    -9.51   0.000     .8512549    .8994099
//           7  |   .8231018   .0128865   -12.43   0.000     .7982283    .8487504
//           8  |   .8373453   .0194117    -7.66   0.000     .8001504    .8762691
//           9  |   .7887648   .0188638    -9.92   0.000     .7526455    .8266173
//              |
//        _cons |   50.76849   .8782014   227.03   0.000     49.07609    52.51924
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   47.85711    .885275   209.11   0.000     46.15308    49.62405
//      levels2 |   47.61874   .8674556   212.07   0.000     45.94855    49.34964
//      levels3 |   48.93908   .8869371   214.67   0.000     47.23123    50.70869
//      levels4 |   49.81001    .887262   219.40   0.000     48.10102    51.57973
//      levels5 |   50.76095    .885802   225.04   0.000     49.05417    52.52713
// `
// <br><br>
// Percent difference<br>
// `levels1 |   .9427937   .0129735    -4.28   0.000     .9177059    .9685673`
//
//
// The lowest social distancing counties had 47.8% flu vaccine coverage among Medicare beneficiaries, whereas the most social distancing counties had 50.8% after adjusting for rurality and social distancing orders, a 6.1% (95% CI: 3.2%, 9.0%) difference.

// %%
invert .9427937 .9177059 .9685673
// Out:
// 6.1
// LL: 9
// UL: 3.2

// %% [markdown]
// ---
// # Economic
//
// There is a trend emerging. So, since the places with more social distancing seem to have more health resources, perhaps there are trends in financial means? We explored two baseline economic metrics in relation to social distancing, one representing the overall wealth of the community and one proxy for poverty: 80th percentile of annual household income in dollars and the percent of school-age children eligible for subsidized or free lunches.
//
// ## Household income

// %%
// Comparing 80th percentile income to social distancing
modelrun income80
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -1.943e+09
// Iteration 1:   log pseudolikelihood = -2.162e+08  (backed up)
// Iteration 2:   log pseudolikelihood = -1.453e+08
// Iteration 3:   log pseudolikelihood = -6480089.8
// Iteration 4:   log pseudolikelihood = -3055282.8
// Iteration 5:   log pseudolikelihood = -3044930.3
// Iteration 6:   log pseudolikelihood = -3044929.5
// Iteration 7:   log pseudolikelihood = -3044929.5
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -26433.012
// Iteration 1:   log pseudolikelihood = -23506.902
// Iteration 2:   log pseudolikelihood = -23495.233
// Iteration 3:   log pseudolikelihood = -23495.099
// Iteration 4:   log pseudolikelihood = -23495.098
//
// Negative binomial regression                    Number of obs     =      2,120
// Dispersion           = mean                     Wald chi2(14)     =   1.10e+07
// Log pseudolikelihood = -23495.098               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//     income80 |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   122067.9   2163.157   660.93   0.000       117901    126382.1
//      levels2 |     121852   2059.432   692.89   0.000     117881.7    125956.1
//      levels3 |   126984.4   2209.364   675.44   0.000     122727.1    131389.4
//      levels4 |   133271.6   2324.156   676.64   0.000     128793.3    137905.6
//      levels5 |   141855.2   2694.797   624.45   0.000     136670.6    147236.5
//    homeorder |   .9258548   .0103251    -6.91   0.000     .9058376    .9463143
//              |
//         rucc |
//           2  |   .8411899   .0127612   -11.40   0.000     .8165465     .866577
//           3  |   .8071885   .0120927   -14.30   0.000     .7838319    .8312411
//           4  |   .7549232   .0119901   -17.70   0.000     .7317851    .7787929
//           5  |   .8005734   .0171019   -10.41   0.000     .7677463     .834804
//           6  |   .7176101   .0102557   -23.22   0.000     .6977881    .7379952
//           7  |   .7295939   .0118241   -19.45   0.000     .7067834    .7531406
//           8  |   .6925367    .013339   -19.07   0.000     .6668801    .7191804
//           9  |   .6895036   .0157973   -16.23   0.000     .6592263    .7211714
// -------------+----------------------------------------------------------------
//     /lnalpha |  -3.591335   .0380524                     -3.665916   -3.516754
// -------------+----------------------------------------------------------------
//        alpha |   .0275615   .0010488                      .0255807    .0296957
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(income80)  mean(income80)   sem(income80)
// ----------+-----------------------------------------------
//         1 |            421        86724.15        704.3175
//         2 |            422       89383.908        740.4169
//         3 |            423       94331.669         937.814
//         4 |            429       101312.71        1042.907
//         5 |            425       111441.58        1523.367
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -3044931.4
// Iteration 1:   log pseudolikelihood = -3044929.5
// Iteration 2:   log pseudolikelihood = -3044929.5
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -26455.807
// Iteration 1:   log pseudolikelihood = -24108.493
// Iteration 2:   log pseudolikelihood = -24108.094
// Iteration 3:   log pseudolikelihood = -24108.094
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -23643.605
// Iteration 1:   log pseudolikelihood =  -23522.03
// Iteration 2:   log pseudolikelihood = -23495.119
// Iteration 3:   log pseudolikelihood = -23495.098
// Iteration 4:   log pseudolikelihood = -23495.098
//
// Negative binomial regression                    Number of obs     =      2,120
//                                                 Wald chi2(13)     =    1129.71
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -23495.098               Pseudo R2         =     0.0254
//
// ------------------------------------------------------------------------------
//              |               Robust
//     income80 |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .8605107   .0113397   -11.40   0.000       .83857    .8830256
//      levels2 |   .8589889     .01077   -12.12   0.000     .8381374    .8803591
//      levels3 |   .8951692   .0116544    -8.51   0.000      .872616    .9183053
//      levels4 |   .9394905   .0122666    -4.78   0.000     .9157534    .9638428
//      levels5 |          1  (omitted)
//    homeorder |   .9258548   .0103251    -6.91   0.000     .9058376    .9463143
//              |
//         rucc |
//           2  |   .8411899   .0127612   -11.40   0.000     .8165465     .866577
//           3  |   .8071885   .0120927   -14.30   0.000     .7838319    .8312411
//           4  |   .7549232   .0119901   -17.70   0.000     .7317851    .7787929
//           5  |   .8005734   .0171019   -10.41   0.000     .7677463     .834804
//           6  |   .7176101   .0102557   -23.22   0.000     .6977881    .7379952
//           7  |   .7295939   .0118241   -19.45   0.000     .7067834    .7531406
//           8  |   .6925367    .013339   -19.07   0.000     .6668801    .7191804
//           9  |   .6895036   .0157973   -16.23   0.000     .6592263    .7211714
//              |
//        _cons |   141855.2   2694.797   624.45   0.000     136670.6    147236.5
// -------------+----------------------------------------------------------------
//     /lnalpha |  -3.591335   .0380524                     -3.665916   -3.516754
// -------------+----------------------------------------------------------------
//        alpha |   .0275615   .0010488                      .0255807    .0296957
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   120578.2    2174.73   648.71   0.000     116390.3    124916.8
//      levels2 |   121964.6   2103.959   678.90   0.000     117909.8    126158.7
//      levels3 |   127609.2   2292.704   654.37   0.000     123193.8    132182.9
//      levels4 |     132518   2338.222   668.45   0.000     128013.5      137181
//      levels5 |   140685.7   2682.181   621.78   0.000     135525.8    146042.2
// `
// <br><br>
// Percent difference<br>
// `levels1 |   .8570749   .0113487   -11.65   0.000     .8351179    .8796091`
//
//
// The lowest social distancing counties the 80th percentile of annual houshold income was `$120,578`, whereas in the most social distancing counties it was `$140,685`, after adjusting for rurality and social distancing orders, a 17% (95% CI: 14%, 20%) difference.

// %%
invert .8570749 .8351179 .8796091
// Out:
// 16.7
// LL: 19.7
// UL: 13.7

// %% [markdown]
// ---
//
// ## Subsidized lunches

// %%
modelrun schoollunch
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -236577.22
// Iteration 1:   log pseudolikelihood =  -29179.38
// Iteration 2:   log pseudolikelihood = -14755.373
// Iteration 3:   log pseudolikelihood = -10927.184
// Iteration 4:   log pseudolikelihood =  -10927.02
// Iteration 5:   log pseudolikelihood =  -10927.02
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -10170.826
// Iteration 1:   log pseudolikelihood = -9326.5547
// Iteration 2:   log pseudolikelihood =  -8632.601
// Iteration 3:   log pseudolikelihood =  -8557.674
// Iteration 4:   log pseudolikelihood = -8555.2061
// Iteration 5:   log pseudolikelihood = -8555.2025
// Iteration 6:   log pseudolikelihood = -8555.2025
//
// Negative binomial regression                    Number of obs     =      2,036
// Dispersion           = mean                     Wald chi2(14)     =  377454.79
// Log pseudolikelihood = -8555.2025               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//  schoollunch |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   40.57064   1.355432   110.84   0.000     37.99915    43.31614
//      levels2 |    40.4291   1.317116   113.56   0.000     37.92829     43.0948
//      levels3 |   37.33904   1.291273   104.68   0.000     34.89205    39.95763
//      levels4 |    34.6208   1.153531   106.38   0.000     32.43216    36.95713
//      levels5 |   32.76692   1.121889   101.92   0.000     30.64022    35.04124
//    homeorder |   1.287715   .0288104    11.30   0.000     1.232468    1.345439
//              |
//         rucc |
//           2  |   1.133459   .0322553     4.40   0.000     1.071971    1.198474
//           3  |   1.115512   .0322524     3.78   0.000     1.054056    1.180551
//           4  |   1.200934   .0365794     6.01   0.000     1.131338    1.274812
//           5  |   1.171267   .0506475     3.66   0.000      1.07609    1.274862
//           6  |   1.289087   .0339907     9.63   0.000     1.224158    1.357459
//           7  |   1.229351   .0344242     7.37   0.000     1.163698    1.298707
//           8  |   1.233954   .0460713     5.63   0.000      1.14688    1.327638
//           9  |   1.284621   .0470584     6.84   0.000     1.195622    1.380246
// -------------+----------------------------------------------------------------
//     /lnalpha |  -2.584443   .0423999                     -2.667546   -2.501341
// -------------+----------------------------------------------------------------
//        alpha |   .0754381   .0031986                      .0694224     .081975
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(school~h)  mean(school~h)   sem(school~h)
// ----------+-----------------------------------------------
//         1 |            400       60.339123        .9460364
//         2 |            398       59.566838         .876272
//         3 |            403       54.907918        .9108519
//         4 |            423       50.399013        .8076111
//         5 |            412       47.312944        .7834651
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood =  -10927.02
// Iteration 1:   log pseudolikelihood =  -10927.02
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -10191.642
// Iteration 1:   log pseudolikelihood = -9563.6586
// Iteration 2:   log pseudolikelihood = -9312.5064
// Iteration 3:   log pseudolikelihood = -8900.5706
// Iteration 4:   log pseudolikelihood = -8759.0089
// Iteration 5:   log pseudolikelihood = -8759.0075
// Iteration 6:   log pseudolikelihood = -8759.0075
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -8575.4324
// Iteration 1:   log pseudolikelihood = -8555.2913
// Iteration 2:   log pseudolikelihood = -8555.2025
// Iteration 3:   log pseudolikelihood = -8555.2025
//
// Negative binomial regression                    Number of obs     =      2,036
//                                                 Wald chi2(13)     =     401.16
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -8555.2025               Pseudo R2         =     0.0233
//
// ------------------------------------------------------------------------------
//              |               Robust
//  schoollunch |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.238158   .0275331     9.61   0.000     1.185353    1.293315
//      levels2 |   1.233839     .02687     9.65   0.000     1.182282    1.287643
//      levels3 |   1.139534   .0262781     5.66   0.000     1.089177     1.19222
//      levels4 |   1.056578   .0241624     2.41   0.016     1.010266    1.105012
//      levels5 |          1  (omitted)
//    homeorder |   1.287715   .0288104    11.30   0.000     1.232468    1.345439
//              |
//         rucc |
//           2  |   1.133459   .0322553     4.40   0.000     1.071971    1.198474
//           3  |   1.115512   .0322524     3.78   0.000     1.054056    1.180551
//           4  |   1.200934   .0365794     6.01   0.000     1.131338    1.274812
//           5  |   1.171267   .0506475     3.66   0.000      1.07609    1.274862
//           6  |   1.289087   .0339907     9.63   0.000     1.224158    1.357459
//           7  |   1.229351   .0344242     7.37   0.000     1.163698    1.298707
//           8  |   1.233954   .0460713     5.63   0.000      1.14688    1.327638
//           9  |   1.284621   .0470584     6.84   0.000     1.195622    1.380246
//              |
//        _cons |   32.76692   1.121889   101.92   0.000     30.64022    35.04124
// -------------+----------------------------------------------------------------
//     /lnalpha |  -2.584443   .0423999                     -2.667546   -2.501341
// -------------+----------------------------------------------------------------
//        alpha |   .0754381   .0031986                      .0694224     .081975
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   41.84078   1.429248   109.31   0.000     39.13122    44.73796
//      levels2 |   41.01835   1.338739   113.80   0.000     38.47663    43.72797
//      levels3 |   37.65352   1.314916   103.90   0.000     35.16255    40.32095
//      levels4 |   35.03891   1.189645   104.75   0.000     32.78313     37.4499
//      levels5 |   33.73666   1.146257   103.56   0.000     31.56321    36.05978
// `
// <br><br>
// Percent difference<br>
// `levels1 |   1.240217   .0277847     9.61   0.000     1.186938    1.295887`
//
//
// In the lowest social distancing counties, 42% of schoolage children were eligible for free or reduced price lunches. By comparison, in the the most social distancing counties 34% were eligible, after adjusting for rurality and social distancing orders, a 24% (95% CI: 19%, 29%) difference.

// %% [markdown]
// ---
// # Structural
// Three lifestyle metrics were selected to provide a diverse snapshot of baseline structural factors that could influence defiance of prolonged stay-at-home orders. The percent of people experiencing food insecurity was derived from Map the Meal Gap project, based on responses from the Current Population Survey and a cost-of-food index. Access to exercise opportunities was the percent of population with adequate access to locations for physical activity. The percent of households with overcrowding was based on the Comprehensive Housing Affordability Strategy measurements.
//
// ## Food insecurity

// %%
modelpoisson foodinsec
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
// note: foodinsec has noninteger values
//
// Iteration 0:   log likelihood = -5807.2302
// Iteration 1:   log likelihood =  -5805.307
// Iteration 2:   log likelihood = -5805.3069
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,106
//                                                   Scale parameter =          1
// Deviance         =  2213.266888                   (1/df) Deviance =   1.050934
// Pearson          =  2304.855027                   (1/df) Pearson  =   1.094423
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.489912
// Log likelihood   = -5805.306878                   BIC             =  -13916.95
//
// ------------------------------------------------------------------------------
//              |                 OIM
//    foodinsec |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   12.84118   .3576404    91.65   0.000     12.15901    13.56163
//      levels2 |   12.30843   .3403766    90.77   0.000     11.65906    12.99396
//      levels3 |   11.64915    .322252    88.75   0.000     11.03436    12.29819
//      levels4 |   10.82297   .2964861    86.94   0.000     10.25719    11.41995
//      levels5 |   10.07298    .276355    84.19   0.000      9.54564    10.62945
//    homeorder |   1.093157   .0206864     4.71   0.000     1.053355    1.134462
//              |
//         rucc |
//           2  |   1.091023   .0253648     3.75   0.000     1.042425    1.141888
//           3  |   1.093882   .0262861     3.73   0.000     1.043556    1.146634
//           4  |   1.142411   .0308302     4.93   0.000     1.083555    1.204464
//           5  |   1.097775   .0402631     2.54   0.011      1.02163    1.179595
//           6  |   1.163415   .0250535     7.03   0.000     1.115333     1.21357
//           7  |   1.111345   .0262007     4.48   0.000     1.061161    1.163903
//           8  |    1.19516   .0389585     5.47   0.000     1.121191    1.274009
//           9  |   1.180371   .0389557     5.02   0.000     1.106436    1.259246
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(foodin~c)  mean(foodin~c)   sem(foodin~c)
// ----------+-----------------------------------------------
//         1 |            421       15.538717        .2247196
//         2 |            422        14.80782        .2003487
//         3 |            423       13.975414        .1945602
//         4 |            429       12.888811        .1846627
//         5 |            425       11.904471         .154996
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
// note: foodinsec has noninteger values
//
// Iteration 0:   log likelihood = -5807.2302
// Iteration 1:   log likelihood =  -5805.307
// Iteration 2:   log likelihood = -5805.3069
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,106
//                                                   Scale parameter =          1
// Deviance         =  2213.266888                   (1/df) Deviance =   1.050934
// Pearson          =  2304.855027                   (1/df) Pearson  =   1.094423
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.489912
// Log likelihood   = -5805.306878                   BIC             =  -13916.95
//
// ------------------------------------------------------------------------------
//              |                 OIM
//    foodinsec |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.274815   .0261768    11.82   0.000     1.224528    1.327167
//      levels2 |   1.221925   .0248481     9.86   0.000     1.174181     1.27161
//      levels3 |   1.156475   .0235313     7.14   0.000     1.111262    1.203527
//      levels4 |   1.074455   .0220384     3.50   0.000     1.032118     1.11853
//      levels5 |          1  (omitted)
//    homeorder |   1.093157   .0206864     4.71   0.000     1.053355    1.134462
//              |
//         rucc |
//           2  |   1.091023   .0253648     3.75   0.000     1.042425    1.141888
//           3  |   1.093882   .0262861     3.73   0.000     1.043556    1.146634
//           4  |   1.142411   .0308302     4.93   0.000     1.083555    1.204464
//           5  |   1.097775   .0402631     2.54   0.011      1.02163    1.179595
//           6  |   1.163415   .0250535     7.03   0.000     1.115333     1.21357
//           7  |   1.111345   .0262007     4.48   0.000     1.061161    1.163903
//           8  |    1.19516   .0389585     5.47   0.000     1.121191    1.274009
//           9  |   1.180371   .0389557     5.02   0.000     1.106436    1.259246
//              |
//        _cons |   10.07298    .276355    84.19   0.000      9.54564    10.62945
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   13.16074    .371045    91.41   0.000     12.45323    13.90844
//      levels2 |    12.5652   .3522368    90.28   0.000     11.89345    13.27489
//      levels3 |   11.63859   .3279836    87.09   0.000     11.01318    12.29951
//      levels4 |    10.9946   .3073966    85.75   0.000     10.40833     11.6139
//      levels5 |   10.41177   .2879299    84.72   0.000     9.862455    10.99167
// `
// <br><br>
// Percent difference<br>
// `levels1 |   1.264025    .025903    11.43   0.000     1.214263    1.315828`
//
//
// The lowest social distancing counties had greater food insecurity, among 13.2% of residents. The most social distancing counties had 10.4%, after adjusting for rurality and social distancing orders, a 26.4% (95% CI: 21.4%, 31.5%) difference.
//
// ---

// %% [markdown]
// ## Exercise opportunities

// %%
modelrun exercise
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -325061.83
// Iteration 1:   log pseudolikelihood = -18550.508
// Iteration 2:   log pseudolikelihood = -13074.377
// Iteration 3:   log pseudolikelihood = -12891.654
// Iteration 4:   log pseudolikelihood = -12891.508
// Iteration 5:   log pseudolikelihood = -12891.508
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -10997.805
// Iteration 1:   log pseudolikelihood = -10155.177
// Iteration 2:   log pseudolikelihood = -9663.6487
// Iteration 3:   log pseudolikelihood = -9591.0507
// Iteration 4:   log pseudolikelihood = -9589.8603
// Iteration 5:   log pseudolikelihood = -9589.8594
//
// Negative binomial regression                    Number of obs     =      2,120
// Dispersion           = mean                     Wald chi2(14)     =  623023.46
// Log pseudolikelihood = -9589.8594               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//     exercise |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   69.33199   1.957176   150.16   0.000     65.60018    73.27608
//      levels2 |   74.18823   1.939088   164.77   0.000     70.48339     78.0878
//      levels3 |   78.13633   1.938713   175.66   0.000     74.42743    82.03004
//      levels4 |   82.51227   1.980358   183.87   0.000     78.72072    86.48644
//      levels5 |   90.87505   2.074198   197.57   0.000     86.89929    95.03271
//    homeorder |   .9333297    .016786    -3.84   0.000     .9010029    .9668164
//              |
//         rucc |
//           2  |   .9359784   .0184701    -3.35   0.001     .9004688    .9728882
//           3  |   .9353832   .0207498    -3.01   0.003     .8955858    .9769492
//           4  |   .9315033   .0191935    -3.44   0.001     .8946342    .9698918
//           5  |   1.036537   .0238234     1.56   0.118     .9908801    1.084298
//           6  |   .7962328   .0162097   -11.19   0.000     .7650879    .8286455
//           7  |   .8950229   .0200981    -4.94   0.000     .8564856    .9352942
//           8  |   .6188039   .0364366    -8.15   0.000     .5513563    .6945025
//           9  |   .6647783   .0360486    -7.53   0.000     .5977494    .7393236
// -------------+----------------------------------------------------------------
//     /lnalpha |  -2.304458    .072425                     -2.446408   -2.162508
// -------------+----------------------------------------------------------------
//        alpha |   .0998129   .0072289                      .0866041    .1150363
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(exercise)  mean(exercise)   sem(exercise)
// ----------+-----------------------------------------------
//         1 |            421       56.304149         1.08992
//         2 |            422       61.824488        .9346537
//         3 |            423       65.122985        .9722155
//         4 |            429        69.82593        .9521532
//         5 |            425       78.021244        .8613853
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -12891.515
// Iteration 1:   log pseudolikelihood = -12891.508
// Iteration 2:   log pseudolikelihood = -12891.508
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -11026.084
// Iteration 1:   log pseudolikelihood = -10366.407
// Iteration 2:   log pseudolikelihood = -9812.2667
// Iteration 3:   log pseudolikelihood = -9810.8496
// Iteration 4:   log pseudolikelihood = -9810.8494
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -9614.6139
// Iteration 1:   log pseudolikelihood = -9590.0418
// Iteration 2:   log pseudolikelihood = -9589.8595
// Iteration 3:   log pseudolikelihood = -9589.8594
//
// Negative binomial regression                    Number of obs     =      2,120
//                                                 Wald chi2(13)     =     563.36
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -9589.8594               Pseudo R2         =     0.0225
//
// ------------------------------------------------------------------------------
//              |               Robust
//     exercise |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .7629375   .0177169   -11.65   0.000     .7289913    .7984644
//      levels2 |   .8163763   .0158057   -10.48   0.000     .7859781    .8479502
//      levels3 |   .8598214    .015332    -8.47   0.000     .8302903    .8904028
//      levels4 |   .9079749   .0150035    -5.84   0.000     .8790396    .9378625
//      levels5 |          1  (omitted)
//    homeorder |   .9333296    .016786    -3.84   0.000     .9010028    .9668162
//              |
//         rucc |
//           2  |   .9359784   .0184701    -3.35   0.001     .9004689    .9728883
//           3  |   .9353834   .0207498    -3.01   0.003     .8955859    .9769493
//           4  |   .9315036   .0191935    -3.44   0.001     .8946345    .9698921
//           5  |   1.036537   .0238234     1.56   0.118     .9908803    1.084298
//           6  |    .796233   .0162097   -11.19   0.000     .7650881    .8286458
//           7  |   .8950233   .0200981    -4.94   0.000     .8564859    .9352946
//           8  |   .6188041   .0364366    -8.15   0.000     .5513564    .6945026
//           9  |   .6647783   .0360486    -7.53   0.000     .5977494    .7393236
//              |
//        _cons |   90.87505   2.074198   197.57   0.000     86.89929    95.03271
// -------------+----------------------------------------------------------------
//     /lnalpha |  -2.304457    .072425                     -2.446407   -2.162507
// -------------+----------------------------------------------------------------
//        alpha |    .099813    .007229                      .0866042    .1150364
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   69.32704   2.008161   146.34   0.000     65.50076    73.37684
//      levels2 |   73.66608    1.99158   159.03   0.000     69.86427    77.67477
//      levels3 |   78.57573   2.050318   167.25   0.000     74.65821    82.69881
//      levels4 |   82.82771   2.039621   179.36   0.000     78.92507    86.92334
//      levels5 |   92.01346   2.177853   191.05   0.000     87.84245    96.38254
// `
// <br><br>
// Percent difference<br>
// ` levels1 |   .7534445    .017626   -12.10   0.000     .7196781    .7887951`
//
//
// In the lowest social distancing counties, 69% of residents had access to physical spaces for exercise, whereas in the most social distancing counties 92% had access, after adjusting for rurality and social distancing orders, a 33% (95% CI: 27%, 39%) difference.

// %%
invert .7534445 .7196781 .7887951
// Out:
// 32.7
// LL: 39
// UL: 26.8

// %% [markdown]
// ---
//
// ## Overcrowding

// %%
modelpoisson overcrowding
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
// note: overcrowding has noninteger values
//
// Iteration 0:   log likelihood = -3934.9643
// Iteration 1:   log likelihood = -3924.7847
// Iteration 2:   log likelihood = -3924.7739
// Iteration 3:   log likelihood = -3924.7739
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,106
//                                                   Scale parameter =          1
// Deviance         =   2280.53109                   (1/df) Deviance =   1.082873
// Pearson          =   3025.50679                   (1/df) Pearson  =   1.436613
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   3.715824
// Log likelihood   =  -3924.77386                   BIC             =  -13849.68
//
// ------------------------------------------------------------------------------
//              |                 OIM
// overcrowding |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   2.365028   .1784498    11.41   0.000     2.039906    2.741969
//      levels2 |   2.233917   .1672232    10.74   0.000     1.929075    2.586932
//      levels3 |   2.142011   .1603548    10.18   0.000     1.849691    2.480528
//      levels4 |   2.086102   .1536257     9.98   0.000     1.805722    2.410017
//      levels5 |   1.986928   .1460399     9.34   0.000     1.720356    2.294804
//    homeorder |   1.181143   .0629599     3.12   0.002     1.063971    1.311219
//              |
//         rucc |
//           2  |   1.007947   .0607388     0.13   0.895     .8956628    1.134308
//           3  |   .9357683   .0597098    -1.04   0.298     .8257614     1.06043
//           4  |   .9401368   .0687014    -0.84   0.398      .814683    1.084909
//           5  |   1.148396    .106623     1.49   0.136     .9573297    1.377595
//           6  |   1.040296   .0583871     0.70   0.482     .9319294    1.161265
//           7  |   .9938604   .0615704    -0.10   0.921     .8802231    1.122168
//           8  |   .9245935     .08478    -0.86   0.393     .7725035    1.106627
//           9  |   .8017114   .0786711    -2.25   0.024     .6614402    .9717298
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(overcr~g)  mean(overcr~g)   sem(overcr~g)
// ----------+-----------------------------------------------
//         1 |            421       2.6592739        .1050306
//         2 |            422       2.5596091        .0841882
//         3 |            423       2.4438029        .0897278
//         4 |            429       2.4009813        .0964641
//         5 |            425       2.3036863        .0874417
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
// note: overcrowding has noninteger values
//
// Iteration 0:   log likelihood = -3934.9643
// Iteration 1:   log likelihood = -3924.7847
// Iteration 2:   log likelihood = -3924.7739
// Iteration 3:   log likelihood = -3924.7739
//
// Generalized linear models                         Number of obs   =      2,120
// Optimization     : ML                             Residual df     =      2,106
//                                                   Scale parameter =          1
// Deviance         =   2280.53109                   (1/df) Deviance =   1.082873
// Pearson          =   3025.50679                   (1/df) Pearson  =   1.436613
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   3.715824
// Log likelihood   =  -3924.77386                   BIC             =  -13849.68
//
// ------------------------------------------------------------------------------
//              |                 OIM
// overcrowding |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.190294   .0656153     3.16   0.002     1.068394    1.326102
//      levels2 |   1.124307   .0612468     2.15   0.031     1.010452    1.250992
//      levels3 |   1.078052   .0585497     1.38   0.166      .969193    1.199137
//      levels4 |   1.049913   .0566211     0.90   0.366     .9446018    1.166966
//      levels5 |          1  (omitted)
//    homeorder |   1.181143   .0629599     3.12   0.002     1.063971    1.311219
//              |
//         rucc |
//           2  |   1.007947   .0607388     0.13   0.895     .8956628    1.134308
//           3  |   .9357683   .0597098    -1.04   0.298     .8257614     1.06043
//           4  |   .9401368   .0687014    -0.84   0.398      .814683    1.084909
//           5  |   1.148396    .106623     1.49   0.136     .9573297    1.377595
//           6  |   1.040296   .0583871     0.70   0.482     .9319294    1.161265
//           7  |   .9938604   .0615704    -0.10   0.921     .8802231    1.122168
//           8  |   .9245935     .08478    -0.86   0.393     .7725035    1.106627
//           9  |   .8017114   .0786711    -2.25   0.024     .6614402    .9717298
//              |
//        _cons |   1.986928   .1460399     9.34   0.000     1.720356    2.294804
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// Relative effect measures <br>
// `    ^
//      levels1 |   2.386115    .182761    11.35   0.000       2.0535    2.772604
//      levels2 |   2.272371   .1727998    10.79   0.000     1.957721    2.637594
//      levels3 |   2.148765   .1640225    10.02   0.000      1.85018    2.495537
//      levels4 |   2.101588   .1584565     9.85   0.000     1.812877    2.436278
//      levels5 |   2.055545   .1525507     9.71   0.000     1.777279    2.377378
// `
// <br><br>
// Percent difference<br>
// `levels1 |   1.160819   .0639501     2.71   0.007     1.042008    1.293176`
//
//
// The lowest social distancing counties had 16% (95% CI: 4.2%, 29%) less overcrowding, after adjusting for rurality and social distancing orders.

// %% [markdown]
// ---
//
// # Exploratory analyses

// %%
frame change default
foreach var of varlist drivealone_p {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (mean) `var', by(iso5)
                    la var `var' "% of Drivers"
                        line `var' iso5, note("Commuting Alone by Vehicle")  
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(drivea~p)  mean(drivea~p)   sem(drivea~p)
// ----------+-----------------------------------------------
//         1 |            421       81.546053        .2877253
//         2 |            422       82.280655         .203786
//         3 |            423       81.368395        .2170131
//         4 |            429       80.060045        .2852762
//         5 |            425        77.45975         .420919
// ----------------------------------------------------------
// This front-end cannot display the desired image type.

// %% [markdown]
// ---

// %%
frame change default
foreach var of varlist rucc {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (median) `var', by(iso5)
                    la var `var' "Meidan RUCC"
                        line `var' iso5, note("Urban-Rural")   
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(rucc)  mean(rucc)   sem(rucc)
// ----------+-----------------------------------
//         1 |        421   5.5296912    .1072763
//         2 |        422   4.5900474    .1096507
//         3 |        423   4.4326243    .1204507
//         4 |        429    3.939394    .1166961
//         5 |        425   3.4917648    .1201696
// ----------------------------------------------
// This front-end cannot display the desired image type.

// %%
frame change default
foreach var of varlist longcommute_p {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (mean) `var', by(iso5)
                    la var `var' "% of Solo Commuters Driving 30+ mins"
                        line `var' iso5, note("Long Solo Commute")     
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(longco~p)  mean(longco~p)   sem(longco~p)
// ----------+-----------------------------------------------
//         1 |            421       28.734917        .5992387
//         2 |            422       30.819905        .6069511
//         3 |            423       31.777069        .5971413
//         4 |            429       32.222378         .592961
//         5 |            425       33.608471        .5601025
// ----------------------------------------------------------
// This front-end cannot display the desired image type.

// %% [markdown]
// ---
//
// # External validation with Google data
//
// Correlations between March 1 to April 11 in Google and DL data by county-day

// %%
// Import Descartes Labs data
clear
import delimited "https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv", encoding(ISO-8859-9) stringcols(6) 

    * Drop state aggregates
        drop if admin2==""

    * Format date
        gen date2=date(date,"YMD")
            format date2 %td
                drop date
                    rename date2 date

    * Note data start and end dates for graphs
        su date 
            local latest: disp %td r(max)
                di "`latest'"
            local earliest: disp %td r(min)
                di "`earliest'"

    * Rename variables for consistency
        rename admin1 state
        rename admin2 county

save dl_x_valid, replace

// Process Google app check-in data
clear
import delimited "/Users/nabarun/Documents/GitHub/covid/fips-google-mobility-daily-as-of-04-20-20.csv", stringcols(1) numericcols(5 6 8)  

    * Format date
        gen date=date(report_date, "YMD")
            format date %td
                order date, first
                    drop report_date

    * Note data start and end dates for graphs
        su date 
            local latest: disp %td r(max)
                di "Latest: " "`latest'"
            local earliest: disp %td r(min)
                di "Earliest: " "`earliest'"

    save google_x_valid, replace
    

// Merge by date and county, retain
    merge 1:1 date fips using dl_x_valid

    tab _merge
        keep if _merge==3
            drop _merge country_code admin_level

    * Variable cleanup
    destring retail_and_recreation_percent_ch grocery_and_pharmacy_percent_cha workplaces_percent_change_from_b, replace force
    rename retail_and_recreation_percent_ch retailrec
    rename grocery_and_pharmacy_percent_cha grocery
    rename workplaces_percent_change_from_b work
    rename residential_percent_change_from_ home
    rename parks_percent_change_from_baseli parks
        la var parks "Parks"
    rename transit_stations_percent_change_ transit
                la var transit "Transit"
    
    gen m50i = m50_index-100
            la var m50i "Re-centered at zero"

    * Correlation matrix on complete case data (n=20,891)
    correlate m50i retailrec grocery work home parks transit
        matrix C = r(C)
     
    * Pairwise correlations
    correlate m50i retailrec
    correlate m50i grocery
    correlate m50i work
    correlate m50i home
    correlate m50i parks
    correlate m50i transit
// Out:
// (9 vars, 133,285 obs)
//
// (2,600 observations deleted)
//
//
//
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//         date |    130,685    21999.49    14.43114      21975      22024
//
//
// 19apr2020
//
//
// 01mar2020
//
//
//
// file dl_x_valid.dta saved
//
//
// (8 vars, 152,039 obs)
//
//
//
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//         date |    152,039     21988.1    16.42271      21960      22016
//
//
// Latest: 11apr2020
//
//
// Earliest: 15feb2020
//
// file google_x_valid.dta saved
//
//
//     Result                           # of obs.
//     -----------------------------------------
//     not matched                        69,868
//         from master                    45,611  (_merge==1)
//         from using                     24,257  (_merge==2)
//
//     matched                           106,428  (_merge==3)
//     -----------------------------------------
//
//
//                  _merge |      Freq.     Percent        Cum.
// ------------------------+-----------------------------------
//         master only (1) |     45,611       25.87       25.87
//          using only (2) |     24,257       13.76       39.63
//             matched (3) |    106,428       60.37      100.00
// ------------------------+-----------------------------------
//                   Total |    176,296      100.00
//
// (69,868 observations deleted)
//
//
// retail_and_recreation_percent_ch: contains nonnumeric characters; replaced as in
// > t
// (13341 missing values generated)
// grocery_and_pharmacy_percent_cha: contains nonnumeric characters; replaced as in
// > t
// (17023 missing values generated)
// workplaces_percent_change_from_b: contains nonnumeric characters; replaced as by
// > te
// (4776 missing values generated)
//
//
//
//
//
//
//
//
//
//
//
// (obs=20,891)
//
//              |     m50i retail~c  grocery     work     home    parks  transit
// -------------+---------------------------------------------------------------
//         m50i |   1.0000
//    retailrec |   0.8853   1.0000
//      grocery |   0.7139   0.7586   1.0000
//         work |   0.8409   0.9074   0.6947   1.0000
//         home |  -0.8172  -0.8909  -0.6763  -0.9734   1.0000
//        parks |   0.2286   0.3275   0.2976   0.2522  -0.2897   1.0000
//      transit |   0.7735   0.8349   0.6689   0.8106  -0.8112   0.3485   1.0000
//
//
//
// (obs=93,087)
//
//              |     m50i retail~c
// -------------+------------------
//         m50i |   1.0000
//    retailrec |   0.3319   1.0000
//
//
// (obs=89,405)
//
//              |     m50i  grocery
// -------------+------------------
//         m50i |   1.0000
//      grocery |   0.3176   1.0000
//
//
// (obs=101,652)
//
//              |     m50i     work
// -------------+------------------
//         m50i |   1.0000
//         work |   0.4594   1.0000
//
//
// (obs=49,730)
//
//              |     m50i     home
// -------------+------------------
//         m50i |   1.0000
//         home |  -0.8209   1.0000
//
//
// (obs=27,234)
//
//              |     m50i    parks
// -------------+------------------
//         m50i |   1.0000
//        parks |   0.0556   1.0000
//
//
// (obs=41,425)
//
//              |     m50i  transit
// -------------+------------------
//         m50i |   1.0000
//      transit |   0.6333   1.0000

// %% [markdown]
// ---
//
// *fin.*
