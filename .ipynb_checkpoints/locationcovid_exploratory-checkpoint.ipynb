// %% [markdown]
// <font size=5> Social distancing: evidence of privilege in a pandemic from smartphones </font><br>
// Nabarun Dasgupta, MPH, PhD | nab@unc.edu | @nabarund<br>
// *Dr. Dasgupta is an epidemiologist at the University of North Carolina in Chapel Hill. He studies population level patterns of infectious disease, medication safety, and opioids.*<br>
// Thanks to Ben White for data munging help. Code available on [GitHub](https://github.com/opioiddatalab/covid).<br>
//
// **Co-authors**<br>
// Michele Jonsson Funk, PhD<br>
// Allison Lazard, PhD<br>
// Benjamin Eugene White<br>
// Steve W. Marshall, PhD<br>

// %% [markdown]
// <div class="alert alert-warning">
//
// **Warning:** Code and output provided for evaluation only. Paper under review. Results have not been peer-reviewed and should not be used for clinical or public health interpretation.
//
// </div>

// %% [markdown]
// On March 23, 2020 Stuart Thompson and Yaryna Serkez of *The New York Times* [published](https://www.nytimes.com/interactive/2020/03/23/opinion/coronavirus-economy-recession.html) a fascinating use of cell phone GPS signal information to gauge movement and commuting, during the advent of social distancing. They compared the state-level data in a [slick graphic](https://www.nytimes.com/interactive/2020/03/23/opinion/coronavirus-economy-recession.html) to political leanings. But we wanted to understand more about other community level characteristics of slow versus fast adopters.<br>
// <br>
// We were provided access to the same location dataset on social distancing published today in the. We used a data merging approach we have [previously published](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6339867/). Repurposing code from an ongoing project, we merged in community-level data from the Robert Wood Johnson Foundation's [County Health Rankings](https://www.countyhealthrankings.org/). This very rich dataset contains dozens of explanatory variables about health, social, and economic indicators.<br>
//
// ---

// %%
display "Notebook generated on $S_DATE at $S_TIME ET"
// Out:
// Notebook generated on 21 Apr 2020 at 19:12:37 ET

// %% [markdown]
// # Models

// %%
// Load pre-procesed data
clear all
set scheme economist
use "https://github.com/opioiddatalab/covid/blob/master/analysiset.dta?raw=true"

// Create results frame
frame create results str20 strat level avg LL UL

// Set up negative binomial model
program define modelrun, rclass
    version 16
    syntax varlist(numeric)
    
    frame change default
    foreach var of local varlist {
    
    di "----- RURALITY-ADJUSTED NEGBIN MODEL -----"
       nbreg `var' levels* homeorder i.rucc, irr nocons vce(r)

    * Store results
        frame post results ("`var'") (1) (round((r(table)[1,1]),.1)) (round((r(table)[5,1]),.1)) (round((r(table)[6,1]),.1))
        frame post results ("`var'") (2) (round((r(table)[1,2]),.1)) (round((r(table)[5,2]),.1)) (round((r(table)[6,2]),.1))
        frame post results ("`var'") (3) (round((r(table)[1,3]),.1)) (round((r(table)[5,3]),.1)) (round((r(table)[6,3]),.1))
        frame post results ("`var'") (4) (round((r(table)[1,4]),.1)) (round((r(table)[5,4]),.1)) (round((r(table)[6,4]),.1))
        frame post results ("`var'") (5) (round((r(table)[1,5]),.1)) (round((r(table)[5,5]),.1)) (round((r(table)[6,5]),.1))
        
        di "Compare to tabular data:"
        table iso5, c(count `var' mean `var' sem `var') 

    di "----- PERCENT DIFFERENCE MODEL -----"
    * Rate difference models
        nbreg `var' levels* homeorder i.rucc, irr vce(r)   
   
   * Plot graph
       frame change results
       la var level "Social Distancing: Lowest (1) to Highest (5)"
       line avg level if inlist(strat,"`var'"), title("`var'")

    frame change default
    
    }
end

// Set up scaled Poisson model

program define modelpoisson, rclass
    version 16
    syntax varlist(numeric)
    
    frame change default
    foreach var of local varlist {

    di "----- RURALITY-ADJUSTED POISSON MODEL -----"
       glm `var' levels* homeorder i.rucc, family(poisson) link(log) scale(x2) eform nocons 

    * Store results
        frame post results ("`var'") (1) (round((r(table)[1,1]),.1)) (round((r(table)[5,1]),.1)) (round((r(table)[6,1]),.1))
        frame post results ("`var'") (2) (round((r(table)[1,2]),.1)) (round((r(table)[5,2]),.1)) (round((r(table)[6,2]),.1))
        frame post results ("`var'") (3) (round((r(table)[1,3]),.1)) (round((r(table)[5,3]),.1)) (round((r(table)[6,3]),.1))
        frame post results ("`var'") (4) (round((r(table)[1,4]),.1)) (round((r(table)[5,4]),.1)) (round((r(table)[6,4]),.1))
        frame post results ("`var'") (5) (round((r(table)[1,5]),.1)) (round((r(table)[5,5]),.1)) (round((r(table)[6,5]),.1))
        
        di "Compare to tabular data:"
        table iso5, c(count `var' mean `var' sem `var') 

    di "----- PERCENT DIFFERENCE MODEL -----"
    * Rate difference models
       glm `var' levels* homeorder i.rucc, family(poisson) link(log) scale(x2) eform 
   
   * Plot graph
       frame change results
       la var level "Social Distancing: Lowest (1) to Highest (5)"
       line avg level if inlist(strat,"`var'"), title("`var'")

    frame change default
    
    }
end

// %% [markdown]
// ---
//
// # Descriptive Results

// %%
// Basic distributions of counties and traces
* iso5 is the main outcome variable representing quintiles of mobility change

tab rucc, m
tab iso5, m
table iso5, c(sum last3_sample)
su last3_sample
di "Total 3-day mobile traces: " r(sum)

* US average change in mobility
qui: su last3_index
    return list

* Mean mobility change by quintile
table iso5, c(count last3_index mean last3_index sem last3_index)

* Mobility quintile boundaries 
bysort iso5: su last3_index

* Rurality/urbanicity by quintile
table iso5, c(median rucc)
// Out:
//   RUCC_2013 |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        342       16.12       16.12
//           2 |        308       14.52       30.65
//           3 |        275       12.97       43.61
//           4 |        165        7.78       51.39
//           5 |         74        3.49       54.88
//           6 |        444       20.93       75.81
//           7 |        321       15.13       90.95
//           8 |         98        4.62       95.57
//           9 |         94        4.43      100.00
// ------------+-----------------------------------
//       Total |      2,121      100.00
//
//
// Distancing: |
//  Lowest (1) |
//  to Highest |
//         (5) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        424       19.99       19.99
//           2 |        424       19.99       39.98
//           3 |        423       19.94       59.92
//           4 |        421       19.85       79.77
//           5 |        429       20.23      100.00
// ------------+-----------------------------------
//       Total |      2,121      100.00
//
//
// -------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       | sum(last3_~e)
// ----------+--------------
//         1 |       1040479
//         2 |       1481200
//         3 |       2215266
//         4 |       2649145
//         5 |       6218575
// -------------------------
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// last3_sample |      2,121    6414.269    15083.38        101     285845
//
// Total 3-day mobile traces: 13604665
//
//
//
// scalars:
//                   r(N) =  2121
//               r(sum_w) =  2121
//                r(mean) =  42.09311648764907
//                 r(Var) =  559.3349218681501
//                  r(sd) =  23.65026261731886
//                 r(min) =  0
//                 r(max) =  378.3333435058594
//                 r(sum) =  89279.50007030368
//
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(last3_~x)  mean(last3_~x)   sem(last3_~x)
// ----------+-----------------------------------------------
//         1 |            424        73.09198        1.055634
//         2 |            424         54.3408         .173112
//         3 |            423         42.5327        .1565111
//         4 |            421        29.61124        .2064396
//         5 |            429        11.16628        .3430611
// ----------------------------------------------------------
//
//
// --------------------------------------------------------------------------------
// -> iso5 = 1
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  last3_index |        424    73.09198    21.73683   60.66667   378.3333
//
// --------------------------------------------------------------------------------
// -> iso5 = 2
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  last3_index |        424     54.3408    3.564595   48.33333       60.5
//
// --------------------------------------------------------------------------------
// -> iso5 = 3
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  last3_index |        423     42.5327    3.218957         37         48
//
// --------------------------------------------------------------------------------
// -> iso5 = 4
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  last3_index |        421    29.61124    4.235787   22.66667   36.66667
//
// --------------------------------------------------------------------------------
// -> iso5 = 5
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  last3_index |        429    11.16628    7.105591          0   22.33333
//
//
//
// ----------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |  med(rucc)
// ----------+-----------
//         1 |          6
//         2 |          5
//         3 |          4
//         4 |          3
//         5 |          3
// ----------------------

// %% [markdown]
// ---
// # Healthcare
//
// To gauge overall baseline healthcare access and utilization, we examined primary care providers per 100,000 population and percent uninsured under age 65 (e.g., Medicare eligibility). As a marker for a closely related preventive health behavior, we examined whether earlier influenza vaccination rates were associated with how much the county was likely to slow down in the current coronavirus outbreak. This was quantified as the percent of annual Medicare enrollees having an annual influenza vaccination.
//
// ## Primary care providers
//
// We wanted to see if places with more social distancing had better healthcare resources. So we looked at primary care providers per 100,000 population.

// %%
modelrun pcp_rate
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -261516.18
// Iteration 1:   log pseudolikelihood = -38916.744
// Iteration 2:   log pseudolikelihood = -24624.154
// Iteration 3:   log pseudolikelihood = -21366.846
// Iteration 4:   log pseudolikelihood = -21365.944
// Iteration 5:   log pseudolikelihood = -21365.944
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood =   -10405.3
// Iteration 1:   log pseudolikelihood = -9945.7242
// Iteration 2:   log pseudolikelihood = -9737.8079
// Iteration 3:   log pseudolikelihood = -9737.4047
// Iteration 4:   log pseudolikelihood = -9737.4046
//
// Negative binomial regression                    Number of obs     =      2,075
// Dispersion           = mean                     Wald chi2(14)     =  127325.08
// Log pseudolikelihood = -9737.4046               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//     pcp_rate |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |    49.4269   2.469613    78.06   0.000       44.816    54.51219
//      levels2 |   50.90777   2.527614    79.15   0.000     46.18715    56.11086
//      levels3 |   56.66436   2.832643    80.76   0.000      51.3758    62.49733
//      levels4 |   62.54773   2.997007    86.32   0.000     56.94109    68.70642
//      levels5 |   72.75614   3.547062    87.94   0.000     66.12584    80.05124
//    homeorder |   .9822611   .0321916    -0.55   0.585     .9211504    1.047426
//              |
//         rucc |
//           2  |   1.039297   .0428792     0.93   0.350     .9585636     1.12683
//           3  |   1.148008   .0578355     2.74   0.006     1.040069    1.267148
//           4  |   .9477967   .0420408    -1.21   0.227     .8688784    1.033883
//           5  |    1.32235   .0696972     5.30   0.000     1.192565    1.466259
//           6  |   .8229306   .0333963    -4.80   0.000     .7600105    .8910598
//           7  |   1.071328   .0463643     1.59   0.111     .9842034    1.166166
//           8  |   .6132908    .050771    -5.91   0.000      .521435     .721328
//           9  |   .6528221   .0483886    -5.75   0.000     .5645493    .7548972
// -------------+----------------------------------------------------------------
//     /lnalpha |  -1.350465   .0387973                     -1.426507   -1.274424
// -------------+----------------------------------------------------------------
//        alpha |   .2591196   .0100532                      .2401463     .279592
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(pcp_rate)  mean(pcp_rate)   sem(pcp_rate)
// ----------+-----------------------------------------------
//         1 |            404       47.164356        1.242538
//         2 |            416       48.849595        1.365867
//         3 |            414       54.827679        1.551243
//         4 |            415       59.781052         1.52324
//         5 |            426       70.145484        2.061239
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -21365.968
// Iteration 1:   log pseudolikelihood = -21365.944
// Iteration 2:   log pseudolikelihood = -21365.944
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -10456.009
// Iteration 1:   log pseudolikelihood =  -10043.61
// Iteration 2:   log pseudolikelihood = -9909.4296
// Iteration 3:   log pseudolikelihood =  -9909.381
// Iteration 4:   log pseudolikelihood =  -9909.381
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -9752.3826
// Iteration 1:   log pseudolikelihood = -9737.5616
// Iteration 2:   log pseudolikelihood = -9737.4046
// Iteration 3:   log pseudolikelihood = -9737.4046
//
// Negative binomial regression                    Number of obs     =      2,075
//                                                 Wald chi2(13)     =     344.75
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -9737.4046               Pseudo R2         =     0.0174
//
// ------------------------------------------------------------------------------
//              |               Robust
//     pcp_rate |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .6793503    .027583    -9.52   0.000     .6273836    .7356213
//      levels2 |   .6997041   .0283877    -8.80   0.000     .6462199    .7576149
//      levels3 |   .7788259   .0307247    -6.34   0.000     .7208759    .8414344
//      levels4 |   .8596901   .0329537    -3.94   0.000     .7974687    .9267663
//      levels5 |          1  (omitted)
//    homeorder |   .9822611   .0321916    -0.55   0.585     .9211504    1.047426
//              |
//         rucc |
//           2  |   1.039297   .0428792     0.93   0.350     .9585635     1.12683
//           3  |   1.148007   .0578355     2.74   0.006     1.040069    1.267148
//           4  |   .9477966   .0420408    -1.21   0.227     .8688783    1.033883
//           5  |    1.32235   .0696972     5.30   0.000     1.192565    1.466259
//           6  |   .8229305   .0333963    -4.80   0.000     .7600104    .8910597
//           7  |   1.071328   .0463643     1.59   0.111     .9842032    1.166166
//           8  |   .6132908    .050771    -5.91   0.000      .521435    .7213279
//           9  |    .652822   .0483886    -5.75   0.000     .5645492    .7548971
//              |
//        _cons |   72.75615   3.547063    87.94   0.000     66.12585    80.05125
// -------------+----------------------------------------------------------------
//     /lnalpha |  -1.350465   .0387973                     -1.426507   -1.274424
// -------------+----------------------------------------------------------------
//        alpha |   .2591197   .0100532                      .2401464     .279592
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpretation
// <br><br>
//
// `   pcp_rate |        IRR    [95% Conf. Interval]
// -------------+-----------------------------------
//      levels1 |   50.45689    46.44897    54.81064
//      levels2 |   52.73648    48.70426    57.10253
//      levels3 |   55.07755    50.95751    59.53072
//      levels4 |   59.75643     55.5741    64.25349
//      levels5 |   72.45264    67.53468    77.72872`
//
//
// `levels1 |   .6964121   .0276086    -9.13   0.000     .6443491    .7526818`

// %% [markdown]
// ## Percent uninsured
// Percent of without health insurance below Medicare elgibility (age 65).

// %%
// Comparing percent uninsured to social distancing
modelpoisson uninsured_p
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
// note: uninsured_p has noninteger values
//
// Iteration 0:   log likelihood = -6281.8894
// Iteration 1:   log likelihood = -6275.0834
// Iteration 2:   log likelihood = -6275.0823
// Iteration 3:   log likelihood = -6275.0823
//
// Generalized linear models                         Number of obs   =      2,121
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =  3727.150597                   (1/df) Deviance =   1.768937
// Pearson          =  3912.164223                   (1/df) Pearson  =   1.856746
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.930299
// Log likelihood   = -6275.082298                   BIC             =  -12411.72
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  uninsured_p |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   11.31834   .4589692    59.84   0.000      10.4536    12.25462
//      levels2 |   10.65563    .429903    58.65   0.000      9.84549    11.53244
//      levels3 |   9.304829   .3793602    54.71   0.000     8.590228    10.07888
//      levels4 |   8.544709   .3466857    52.88   0.000     7.891533    9.251949
//      levels5 |   7.267551   .2956462    48.76   0.000     6.710594    7.870734
//    homeorder |   1.122122    .031497     4.10   0.000     1.062057    1.185585
//              |
//         rucc |
//           2  |   1.007766   .0345965     0.23   0.822     .9421887    1.077907
//           3  |   1.002017   .0354259     0.06   0.955     .9349342    1.073912
//           4  |   1.030632   .0418563     0.74   0.458     .9517749    1.116022
//           5  |    1.02487   .0551055     0.46   0.648     .9223615    1.138771
//           6  |   1.129348   .0352308     3.90   0.000     1.062366    1.200554
//           7  |   1.096239   .0373841     2.69   0.007     1.025363    1.172015
//           8  |    1.17224   .0542216     3.44   0.001     1.070643    1.283479
//           9  |   1.114209   .0536766     2.24   0.025     1.013819     1.22454
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(uninsu~p)  mean(uninsu~p)   sem(uninsu~p)
// ----------+-----------------------------------------------
//         1 |            424       13.387752         .228919
//         2 |            424       12.524668         .227815
//         3 |            423       10.905436        .2345342
//         4 |            421       9.9835259        .2172989
//         5 |            429       8.4527579        .1966509
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
// note: uninsured_p has noninteger values
//
// Iteration 0:   log likelihood = -6281.8894
// Iteration 1:   log likelihood = -6275.0834
// Iteration 2:   log likelihood = -6275.0823
// Iteration 3:   log likelihood = -6275.0823
//
// Generalized linear models                         Number of obs   =      2,121
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =  3727.150597                   (1/df) Deviance =   1.768937
// Pearson          =  3912.164223                   (1/df) Pearson  =   1.856746
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.930299
// Log likelihood   = -6275.082298                   BIC             =  -12411.72
//
// ------------------------------------------------------------------------------
//              |                 OIM
//  uninsured_p |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.557381    .047272    14.59   0.000     1.467431    1.652844
//      levels2 |   1.466193   .0443207    12.66   0.000     1.381849    1.555685
//      levels3 |   1.280325    .039328     8.04   0.000     1.205518    1.359774
//      levels4 |   1.175734   .0366721     5.19   0.000     1.106011    1.249853
//      levels5 |          1  (omitted)
//    homeorder |   1.122122    .031497     4.10   0.000     1.062057    1.185585
//              |
//         rucc |
//           2  |   1.007766   .0345965     0.23   0.822     .9421887    1.077907
//           3  |   1.002017   .0354259     0.06   0.955     .9349342    1.073912
//           4  |   1.030632   .0418563     0.74   0.458     .9517749    1.116022
//           5  |    1.02487   .0551055     0.46   0.648     .9223615    1.138771
//           6  |   1.129348   .0352308     3.90   0.000     1.062366    1.200554
//           7  |   1.096239   .0373841     2.69   0.007     1.025363    1.172015
//           8  |    1.17224   .0542216     3.44   0.001     1.070643    1.283479
//           9  |   1.114209   .0536766     2.24   0.025     1.013819     1.22454
//              |
//        _cons |   7.267551   .2956462    48.76   0.000     6.710594    7.870734
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// Graph above: Comparing **percent uninsured** to social distancing
//
// Counties with lower social distancing also had a higher proportion of uninsured residents.

// %% [markdown]
// ## Flu Vaccination
//
// We had a hypothesis that counties that were more involved in preventative behaviors would be more likely to self-isolate more thoroughly. To test this, we examined whether earlier flu vaccination rates impacted how much the county was likely to slow down in the current coronavirus outbreak. This is quantified as the percent of annual Medicare enrollees having an annual flu vaccination, as reported by the Robert Wood Johnson Foundation. Since the flu vaccine is free to all Medicare beneficiaries, and this is the elderly age group with the most influenza mortality, this is a convenient metric to test *a priori* how conscientious the population was, on average.

// %%
// Basic descriptive on background influenza vaccine
frame change default
summ fluvaccine, d
hist fluvaccine, bin(10)
// Out:
//         % Medicare Beneficiaries Getting Flu Vaccine
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%           18              9
//  5%           26              9
// 10%           30             12       Obs               2,118
// 25%           37             12       Sum of Wgt.       2,118
//
// 50%           43                      Mean            41.9745
//                         Largest       Std. Dev.      8.676047
// 75%           48             62
// 90%           52             62       Variance       75.27379
// 95%           54             63       Skewness       -.642207
// 99%           57             65       Kurtosis       3.276425
//
// (bin=10, start=9, width=5.6)
// This front-end cannot display the desired image type.

// %%
// Comparing background flu vaccination with current social distancing
modelpoisson fluvaccine
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
//
// Iteration 0:   log likelihood = -7575.5753
// Iteration 1:   log likelihood = -7573.9667
// Iteration 2:   log likelihood = -7573.9667
//
// Generalized linear models                         Number of obs   =      2,118
// Optimization     : ML                             Residual df     =      2,104
//                                                   Scale parameter =          1
// Deviance         =  3385.689763                   (1/df) Deviance =   1.609168
// Pearson          =  3207.991362                   (1/df) Pearson  =   1.524711
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   7.165219
// Log likelihood   = -7573.966657                   BIC             =  -12727.22
//
// ------------------------------------------------------------------------------
//              |                 OIM
//   fluvaccine |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   47.85711    .885275   209.11   0.000     46.15308    49.62405
//      levels2 |   47.61874   .8674556   212.07   0.000     45.94855    49.34964
//      levels3 |   48.93908   .8869371   214.67   0.000     47.23123    50.70869
//      levels4 |   49.81001    .887262   219.40   0.000     48.10102    51.57973
//      levels5 |   50.76095    .885802   225.04   0.000     49.05417    52.52713
//    homeorder |   .9150303   .0117525    -6.91   0.000     .8922834    .9383571
//              |
//         rucc |
//           2  |   .9864505   .0144218    -0.93   0.351     .9585853    1.015126
//           3  |   1.002757   .0152143     0.18   0.856     .9733767    1.033025
//           4  |   .9773675   .0172523    -1.30   0.195     .9441317    1.011773
//           5  |   .9471155   .0233138    -2.21   0.027     .9025059    .9939299
//           6  |   .8774771   .0123487    -9.29   0.000     .8536048    .9020171
//           7  |   .8269651   .0130093   -12.08   0.000     .8018564      .85286
//           8  |   .8412032   .0191921    -7.58   0.000      .804416    .8796726
//           9  |   .7731626   .0186785   -10.65   0.000     .7374067    .8106523
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(fluvac~e)  mean(fluvac~e)   sem(fluvac~e)
// ----------+-----------------------------------------------
//         1 |            422       39.981041        .4164353
//         2 |            424       40.603775        .4067805
//         3 |            423       42.018913        .4359266
//         4 |            420       43.080952         .420827
//         5 |            429        44.16317        .3956098
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
//
// Iteration 0:   log likelihood = -7575.5753
// Iteration 1:   log likelihood = -7573.9667
// Iteration 2:   log likelihood = -7573.9667
//
// Generalized linear models                         Number of obs   =      2,118
// Optimization     : ML                             Residual df     =      2,104
//                                                   Scale parameter =          1
// Deviance         =  3385.689763                   (1/df) Deviance =   1.609168
// Pearson          =  3207.991362                   (1/df) Pearson  =   1.524711
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   7.165219
// Log likelihood   = -7573.966657                   BIC             =  -12727.22
//
// ------------------------------------------------------------------------------
//              |                 OIM
//   fluvaccine |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .9427937   .0129735    -4.28   0.000     .9177059    .9685673
//      levels2 |   .9380978   .0126062    -4.76   0.000     .9137127    .9631336
//      levels3 |   .9641087   .0126594    -2.78   0.005     .9396133    .9892428
//      levels4 |   .9812662   .0127521    -1.46   0.146     .9565882    1.006581
//      levels5 |          1  (omitted)
//    homeorder |   .9150303   .0117525    -6.91   0.000     .8922834    .9383571
//              |
//         rucc |
//           2  |   .9864505   .0144218    -0.93   0.351     .9585853    1.015126
//           3  |   1.002757   .0152143     0.18   0.856     .9733767    1.033025
//           4  |   .9773675   .0172523    -1.30   0.195     .9441317    1.011773
//           5  |   .9471155   .0233138    -2.21   0.027     .9025059    .9939299
//           6  |   .8774771   .0123487    -9.29   0.000     .8536048    .9020171
//           7  |   .8269651   .0130093   -12.08   0.000     .8018564      .85286
//           8  |   .8412032   .0191921    -7.58   0.000      .804416    .8796726
//           9  |   .7731626   .0186785   -10.65   0.000     .7374067    .8106523
//              |
//        _cons |   50.76095    .885802   225.04   0.000     49.05417    52.52713
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// Grpah above: Comparing background **flu vaccination** with current social distancing<br>
// `levels1 |   .9409152   .0130748    -4.38   0.000      .915635    .9668934`

// %% [markdown]
// ---
// # Economic
//
// There is a trend emerging. So, since the places with more social distancing seem to have more health resources, perhaps there are trends in financial means? We explored two baseline economic metrics in relation to social distancing, one representing the overall wealth of the community and one proxy for poverty: 80th percentile of annual household income in dollars and the percent of school-age children eligible for subsidized or free lunches.
//
// ## Household income

// %%
// Comparing 80th percentile income to social distancing
modelrun income80
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -1.941e+09
// Iteration 1:   log pseudolikelihood = -2.177e+08  (backed up)
// Iteration 2:   log pseudolikelihood = -1.534e+08
// Iteration 3:   log pseudolikelihood =   -6939918
// Iteration 4:   log pseudolikelihood = -3149656.8
// Iteration 5:   log pseudolikelihood = -3085686.9
// Iteration 6:   log pseudolikelihood = -3085673.9
// Iteration 7:   log pseudolikelihood = -3085673.9
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -26442.897
// Iteration 1:   log pseudolikelihood = -23527.201
// Iteration 2:   log pseudolikelihood = -23516.295
// Iteration 3:   log pseudolikelihood = -23516.181
// Iteration 4:   log pseudolikelihood = -23516.181
//
// Negative binomial regression                    Number of obs     =      2,121
// Dispersion           = mean                     Wald chi2(14)     =   1.09e+07
// Log pseudolikelihood = -23516.181               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//     income80 |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   120578.2    2174.73   648.71   0.000     116390.3    124916.8
//      levels2 |   121964.6   2103.959   678.90   0.000     117909.8    126158.7
//      levels3 |   127609.2   2292.704   654.37   0.000     123193.8    132182.9
//      levels4 |     132518   2338.222   668.45   0.000     128013.5      137181
//      levels5 |   140685.7   2682.181   621.78   0.000     135525.8    146042.2
//    homeorder |    .930086   .0104395    -6.46   0.000     .9098484    .9507738
//              |
//         rucc |
//           2  |   .8360514   .0129246   -11.58   0.000     .8110995    .8617708
//           3  |   .8100551   .0124851   -13.67   0.000     .7859505    .8348989
//           4  |   .7538914   .0122867   -17.33   0.000     .7301905    .7783616
//           5  |   .8036053   .0178604    -9.84   0.000      .769351    .8393848
//           6  |    .717959   .0104841   -22.69   0.000     .6977017    .7388044
//           7  |   .7339456   .0120999   -18.76   0.000     .7106092    .7580483
//           8  |   .6923711   .0136172   -18.69   0.000     .6661897    .7195814
//           9  |   .6840459   .0161512   -16.08   0.000     .6531114    .7164456
// -------------+----------------------------------------------------------------
//     /lnalpha |  -3.579239   .0385754                     -3.654845   -3.503633
// -------------+----------------------------------------------------------------
//        alpha |   .0278969   .0010761                      .0258655    .0300879
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(income80)  mean(income80)   sem(income80)
// ----------+-----------------------------------------------
//         1 |            424       86262.146        723.4817
//         2 |            424       89469.899        744.9064
//         3 |            423       95258.021        941.9474
//         4 |            421       100599.63        1053.332
//         5 |            429          110998        1508.747
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood =   -3085676
// Iteration 1:   log pseudolikelihood = -3085673.9
// Iteration 2:   log pseudolikelihood = -3085673.9
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -26465.382
// Iteration 1:   log pseudolikelihood = -24117.682
// Iteration 2:   log pseudolikelihood = -24117.284
// Iteration 3:   log pseudolikelihood = -24117.284
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -23659.406
// Iteration 1:   log pseudolikelihood = -23540.698
// Iteration 2:   log pseudolikelihood = -23516.199
// Iteration 3:   log pseudolikelihood = -23516.181
// Iteration 4:   log pseudolikelihood = -23516.181
//
// Negative binomial regression                    Number of obs     =      2,121
//                                                 Wald chi2(13)     =    1114.59
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -23516.181               Pseudo R2         =     0.0249
//
// ------------------------------------------------------------------------------
//              |               Robust
//     income80 |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |    .857075   .0113487   -11.65   0.000      .835118    .8796092
//      levels2 |   .8669292   .0109894   -11.26   0.000     .8456557    .8887379
//      levels3 |   .9070514   .0118756    -7.45   0.000     .8840719    .9306283
//      levels4 |   .9419437   .0123515    -4.56   0.000     .9180436     .966466
//      levels5 |          1  (omitted)
//    homeorder |    .930086   .0104395    -6.46   0.000     .9098483    .9507738
//              |
//         rucc |
//           2  |   .8360514   .0129246   -11.58   0.000     .8110995    .8617708
//           3  |   .8100551   .0124851   -13.67   0.000     .7859506    .8348989
//           4  |   .7538914   .0122867   -17.33   0.000     .7301905    .7783616
//           5  |   .8036053   .0178604    -9.84   0.000      .769351    .8393847
//           6  |    .717959   .0104841   -22.69   0.000     .6977017    .7388044
//           7  |   .7339456   .0120999   -18.76   0.000     .7106092    .7580483
//           8  |   .6923711   .0136172   -18.69   0.000     .6661897    .7195815
//           9  |   .6840459   .0161512   -16.08   0.000     .6531113    .7164456
//              |
//        _cons |   140685.7    2682.18   621.78   0.000     135525.7    146042.1
// -------------+----------------------------------------------------------------
//     /lnalpha |  -3.579237   .0385754                     -3.654843   -3.503631
// -------------+----------------------------------------------------------------
//        alpha |    .027897   .0010761                      .0258655    .0300879
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// Graph above: Comparing **80th percentile income** to social distancing

// %% [markdown]
// ## Subsidized lunches

// %%
modelrun schoollunch
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -238761.98
// Iteration 1:   log pseudolikelihood = -28915.635
// Iteration 2:   log pseudolikelihood = -14590.994
// Iteration 3:   log pseudolikelihood = -10961.527
// Iteration 4:   log pseudolikelihood = -10961.465
// Iteration 5:   log pseudolikelihood = -10961.465
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -10202.078
// Iteration 1:   log pseudolikelihood = -9362.1586
// Iteration 2:   log pseudolikelihood = -8697.3102
// Iteration 3:   log pseudolikelihood = -8585.7752
// Iteration 4:   log pseudolikelihood = -8579.1901
// Iteration 5:   log pseudolikelihood = -8579.1694
// Iteration 6:   log pseudolikelihood = -8579.1694
//
// Negative binomial regression                    Number of obs     =      2,040
// Dispersion           = mean                     Wald chi2(14)     =  381653.00
// Log pseudolikelihood = -8579.1694               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//  schoollunch |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   41.84078   1.429248   109.31   0.000     39.13122    44.73796
//      levels2 |   41.01835   1.338739   113.80   0.000     38.47663    43.72797
//      levels3 |   37.65352   1.314916   103.90   0.000     35.16255    40.32095
//      levels4 |   35.03891   1.189645   104.75   0.000     32.78313     37.4499
//      levels5 |   33.73666   1.146257   103.56   0.000     31.56321    36.05978
//    homeorder |   1.273704    .028471    10.82   0.000     1.219106    1.330746
//              |
//         rucc |
//           2  |   1.135297   .0326919     4.41   0.000     1.072997    1.201215
//           3  |   1.104585   .0326016     3.37   0.001       1.0425    1.170367
//           4  |   1.191654   .0366583     5.70   0.000     1.121928    1.265713
//           5  |   1.168631   .0517287     3.52   0.000     1.071518    1.274545
//           6  |   1.272059   .0340145     9.00   0.000     1.207109    1.340504
//           7  |   1.218168   .0347838     6.91   0.000     1.151866    1.288287
//           8  |    1.22025   .0451669     5.38   0.000     1.134859    1.312066
//           9  |   1.275848   .0471272     6.60   0.000     1.186745    1.371641
// -------------+----------------------------------------------------------------
//     /lnalpha |   -2.58811   .0418954                     -2.670224   -2.505997
// -------------+----------------------------------------------------------------
//        alpha |   .0751619   .0031489                      .0692367    .0815942
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(school~h)  mean(school~h)   sem(school~h)
// ----------+-----------------------------------------------
//         1 |            403       61.249306        .9608463
//         2 |            404       59.621663        .8488235
//         3 |            404       54.530362        .8741302
//         4 |            413       50.381551        .8312678
//         5 |            416       47.943342        .7914446
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -10961.465
// Iteration 1:   log pseudolikelihood = -10961.465
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -10221.701
// Iteration 1:   log pseudolikelihood = -9588.6253
// Iteration 2:   log pseudolikelihood = -9426.0329
// Iteration 3:   log pseudolikelihood = -8984.9871
// Iteration 4:   log pseudolikelihood = -8773.5536
// Iteration 5:   log pseudolikelihood = -8773.2341
// Iteration 6:   log pseudolikelihood = -8773.2341
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -8597.5928
// Iteration 1:   log pseudolikelihood = -8579.2431
// Iteration 2:   log pseudolikelihood = -8579.1694
// Iteration 3:   log pseudolikelihood = -8579.1694
//
// Negative binomial regression                    Number of obs     =      2,040
//                                                 Wald chi2(13)     =     390.58
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -8579.1694               Pseudo R2         =     0.0221
//
// ------------------------------------------------------------------------------
//              |               Robust
//  schoollunch |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.240217   .0277847     9.61   0.000     1.186938    1.295887
//      levels2 |   1.215839   .0264472     8.98   0.000     1.165093    1.268795
//      levels3 |   1.116101   .0257339     4.76   0.000     1.066786    1.167695
//      levels4 |     1.0386   .0242101     1.62   0.104      .992217    1.087152
//      levels5 |          1  (omitted)
//    homeorder |   1.273704    .028471    10.82   0.000     1.219106    1.330746
//              |
//         rucc |
//           2  |   1.135297   .0326919     4.41   0.000     1.072997    1.201215
//           3  |   1.104585   .0326016     3.37   0.001       1.0425    1.170367
//           4  |   1.191654   .0366583     5.70   0.000     1.121928    1.265713
//           5  |   1.168631   .0517287     3.52   0.000     1.071518    1.274545
//           6  |   1.272059   .0340145     9.00   0.000     1.207109    1.340504
//           7  |   1.218168   .0347838     6.91   0.000     1.151866    1.288287
//           8  |    1.22025   .0451669     5.38   0.000     1.134859    1.312066
//           9  |   1.275848   .0471272     6.60   0.000     1.186745    1.371641
//              |
//        _cons |   33.73666   1.146257   103.56   0.000     31.56321    36.05978
// -------------+----------------------------------------------------------------
//     /lnalpha |   -2.58811   .0418954                     -2.670224   -2.505997
// -------------+----------------------------------------------------------------
//        alpha |   .0751619   .0031489                      .0692367    .0815942
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// interpretation

// %% [markdown]
// ---
// # Structural
// Three lifestyle metrics were selected to provide a diverse snapshot of baseline structural factors that could influence defiance of prolonged stay-at-home orders. The percent of people experiencing food insecurity was derived from Map the Meal Gap project, based on responses from the Current Population Survey and a cost-of-food index. Access to exercise opportunities was the percent of population with adequate access to locations for physical activity. The percent of households with overcrowding was based on the Comprehensive Housing Affordability Strategy measurements.
//
// ## Food insecurity

// %%
modelpoisson foodinsec
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
// note: foodinsec has noninteger values
//
// Iteration 0:   log likelihood = -5832.7996
// Iteration 1:   log likelihood = -5830.8487
// Iteration 2:   log likelihood = -5830.8486
//
// Generalized linear models                         Number of obs   =      2,121
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =   2253.40542                   (1/df) Deviance =   1.069485
// Pearson          =  2345.841908                   (1/df) Pearson  =   1.113356
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.511408
// Log likelihood   = -5830.848624                   BIC             =  -13885.46
//
// ------------------------------------------------------------------------------
//              |                 OIM
//    foodinsec |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   13.16074    .371045    91.41   0.000     12.45323    13.90844
//      levels2 |    12.5652   .3522368    90.28   0.000     11.89345    13.27489
//      levels3 |   11.63859   .3279836    87.09   0.000     11.01318    12.29951
//      levels4 |    10.9946   .3073966    85.75   0.000     10.40833     11.6139
//      levels5 |   10.41177   .2879299    84.72   0.000     9.862455    10.99167
//    homeorder |   1.078196   .0209078     3.88   0.000     1.037986    1.119963
//              |
//         rucc |
//           2  |   1.096455   .0256703     3.93   0.000     1.047279     1.14794
//           3  |   1.086511   .0263243     3.42   0.001     1.036122     1.13935
//           4  |   1.143284   .0313797     4.88   0.000     1.083406    1.206471
//           5  |   1.095501   .0407364     2.45   0.014     1.018499    1.178324
//           6  |    1.15039   .0249696     6.45   0.000     1.102476    1.200385
//           7  |   1.100905   .0262186     4.04   0.000     1.050698    1.153511
//           8  |   1.197745   .0387028     5.58   0.000     1.124241    1.276055
//           9  |   1.177856   .0391386     4.93   0.000     1.103591     1.25712
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(foodin~c)  mean(foodin~c)   sem(foodin~c)
// ----------+-----------------------------------------------
//         1 |            424       15.657075        .2245905
//         2 |            424       14.896226        .1980352
//         3 |            423       13.745863        .1935988
//         4 |            421       12.919715        .1884585
//         5 |            429       12.113054        .1614975
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
// note: foodinsec has noninteger values
//
// Iteration 0:   log likelihood = -5832.7996
// Iteration 1:   log likelihood = -5830.8487
// Iteration 2:   log likelihood = -5830.8486
//
// Generalized linear models                         Number of obs   =      2,121
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =   2253.40542                   (1/df) Deviance =   1.069485
// Pearson          =  2345.841908                   (1/df) Pearson  =   1.113356
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =   5.511408
// Log likelihood   = -5830.848624                   BIC             =  -13885.46
//
// ------------------------------------------------------------------------------
//              |                 OIM
//    foodinsec |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.264025    .025903    11.43   0.000     1.214263    1.315828
//      levels2 |   1.206827   .0245744     9.23   0.000      1.15961    1.255966
//      levels3 |    1.11783   .0228811     5.44   0.000     1.073872    1.163588
//      levels4 |   1.055979   .0218422     2.63   0.008     1.014025    1.099668
//      levels5 |          1  (omitted)
//    homeorder |   1.078196   .0209078     3.88   0.000     1.037986    1.119963
//              |
//         rucc |
//           2  |   1.096455   .0256703     3.93   0.000     1.047279     1.14794
//           3  |   1.086511   .0263243     3.42   0.001     1.036122     1.13935
//           4  |   1.143284   .0313797     4.88   0.000     1.083406    1.206471
//           5  |   1.095501   .0407364     2.45   0.014     1.018499    1.178324
//           6  |    1.15039   .0249696     6.45   0.000     1.102476    1.200385
//           7  |   1.100905   .0262186     4.04   0.000     1.050698    1.153511
//           8  |   1.197745   .0387028     5.58   0.000     1.124241    1.276055
//           9  |   1.177856   .0391386     4.93   0.000     1.103591     1.25712
//              |
//        _cons |   10.41177   .2879299    84.72   0.000     9.862455    10.99167
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// Interpretation

// %% [markdown]
// ## Exercise opportunities

// %%
modelrun exercise
// Out:
// ----- RURALITY-ADJUSTED NEGBIN MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -324313.16
// Iteration 1:   log pseudolikelihood = -18860.329
// Iteration 2:   log pseudolikelihood = -13211.914
// Iteration 3:   log pseudolikelihood = -13014.079
// Iteration 4:   log pseudolikelihood = -13013.902
// Iteration 5:   log pseudolikelihood = -13013.902
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood =  -10997.23
// Iteration 1:   log pseudolikelihood = -10164.779
// Iteration 2:   log pseudolikelihood = -9669.6626
// Iteration 3:   log pseudolikelihood = -9619.0695
// Iteration 4:   log pseudolikelihood = -9618.4004
// Iteration 5:   log pseudolikelihood = -9618.4001
//
// Negative binomial regression                    Number of obs     =      2,121
// Dispersion           = mean                     Wald chi2(14)     =  611116.17
// Log pseudolikelihood = -9618.4001               Prob > chi2       =     0.0000
//
// ------------------------------------------------------------------------------
//              |               Robust
//     exercise |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   69.32704   2.008161   146.34   0.000     65.50076    73.37684
//      levels2 |   73.66608    1.99158   159.03   0.000     69.86427    77.67477
//      levels3 |   78.57573   2.050318   167.25   0.000     74.65821    82.69881
//      levels4 |   82.82771   2.039621   179.36   0.000     78.92507    86.92334
//      levels5 |   92.01346   2.177853   191.05   0.000     87.84245    96.38254
//    homeorder |    .927836   .0177499    -3.92   0.000     .8936909    .9632856
//              |
//         rucc |
//           2  |   .9372288   .0186372    -3.26   0.001     .9014033    .9744782
//           3  |   .9453316   .0208686    -2.55   0.011     .9053021     .987131
//           4  |   .9180797   .0191457    -4.10   0.000     .8813113    .9563821
//           5  |   1.037393   .0250394     1.52   0.128     .9894596    1.087649
//           6  |   .8012512   .0164278   -10.81   0.000     .7696917    .8341049
//           7  |   .8968939   .0203354    -4.80   0.000     .8579098    .9376494
//           8  |   .6002935   .0340651    -8.99   0.000     .5371063    .6709144
//           9  |   .6778131   .0367634    -7.17   0.000     .6094558    .7538374
// -------------+----------------------------------------------------------------
//     /lnalpha |  -2.271343   .0723922                     -2.413229   -2.129456
// -------------+----------------------------------------------------------------
//        alpha |   .1031736    .007469                      .0895258    .1189019
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(exercise)  mean(exercise)   sem(exercise)
// ----------+-----------------------------------------------
//         1 |            424       56.368653        1.095761
//         2 |            424       60.813182        .9408507
//         3 |            423       65.450754         .985251
//         4 |            421       69.482989        .9604523
//         5 |            429       78.326578        .8533065
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: you are responsible for interpretation of non-count dep. variable
// note: levels5 omitted because of collinearity
//
// Fitting Poisson model:
//
// Iteration 0:   log pseudolikelihood = -13013.913
// Iteration 1:   log pseudolikelihood = -13013.902
// Iteration 2:   log pseudolikelihood = -13013.902
//
// Fitting constant-only model:
//
// Iteration 0:   log pseudolikelihood = -11026.839
// Iteration 1:   log pseudolikelihood = -10370.797
// Iteration 2:   log pseudolikelihood = -9843.0238
// Iteration 3:   log pseudolikelihood = -9842.6835
// Iteration 4:   log pseudolikelihood = -9842.6835
//
// Fitting full model:
//
// Iteration 0:   log pseudolikelihood = -9643.9141
// Iteration 1:   log pseudolikelihood = -9618.6035
// Iteration 2:   log pseudolikelihood = -9618.4001
// Iteration 3:   log pseudolikelihood = -9618.4001
//
// Negative binomial regression                    Number of obs     =      2,121
//                                                 Wald chi2(13)     =     587.38
// Dispersion           = mean                     Prob > chi2       =     0.0000
// Log pseudolikelihood = -9618.4001               Pseudo R2         =     0.0228
//
// ------------------------------------------------------------------------------
//              |               Robust
//     exercise |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   .7534445    .017626   -12.10   0.000     .7196781    .7887951
//      levels2 |   .8006011   .0156762   -11.36   0.000     .7704584     .831923
//      levels3 |   .8539589   .0155813    -8.65   0.000     .8239598    .8850503
//      levels4 |   .9001694   .0150427    -6.29   0.000     .8711638    .9301408
//      levels5 |          1  (omitted)
//    homeorder |   .9278359   .0177499    -3.92   0.000     .8936908    .9632855
//              |
//         rucc |
//           2  |   .9372289   .0186372    -3.26   0.001     .9014034    .9744783
//           3  |   .9453317   .0208686    -2.55   0.011     .9053022    .9871311
//           4  |   .9180799   .0191457    -4.10   0.000     .8813115    .9563822
//           5  |   1.037393   .0250394     1.52   0.128     .9894597    1.087649
//           6  |   .8012513   .0164278   -10.81   0.000     .7696917     .834105
//           7  |    .896894   .0203354    -4.80   0.000       .85791    .9376496
//           8  |   .6002936   .0340651    -8.99   0.000     .5371063    .6709144
//           9  |    .677813   .0367634    -7.17   0.000     .6094558    .7538374
//              |
//        _cons |   92.01347   2.177853   191.05   0.000     87.84245    96.38254
// -------------+----------------------------------------------------------------
//     /lnalpha |  -2.271342   .0723922                     -2.413228   -2.129456
// -------------+----------------------------------------------------------------
//        alpha |   .1031736    .007469                      .0895258    .1189019
// ------------------------------------------------------------------------------
// Note: Estimates are transformed only in the first equation.
// Note: _cons estimates baseline incidence rate.
// This front-end cannot display the desired image type.

// %% [markdown]
// Interpretation

// %%
modelpoisson overcrowding
// Out:
// ----- RURALITY-ADJUSTED POISSON MODEL -----
// note: overcrowding has noninteger values
//
// Iteration 0:   log likelihood = -3951.1381
// Iteration 1:   log likelihood = -3940.7532
// Iteration 2:   log likelihood = -3940.7418
// Iteration 3:   log likelihood = -3940.7418
//
// Generalized linear models                         Number of obs   =      2,121
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =   2305.28486                   (1/df) Deviance =   1.094108
// Pearson          =  3075.591558                   (1/df) Pearson  =   1.459702
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =    3.72913
// Log likelihood   = -3940.741843                   BIC             =  -13833.58
//
// ------------------------------------------------------------------------------
//              |                 OIM
// overcrowding |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   2.386115    .182761    11.35   0.000       2.0535    2.772604
//      levels2 |   2.272371   .1727998    10.79   0.000     1.957721    2.637594
//      levels3 |   2.148765   .1640225    10.02   0.000      1.85018    2.495537
//      levels4 |   2.101588   .1584565     9.85   0.000     1.812877    2.436278
//      levels5 |   2.055545   .1525507     9.71   0.000     1.777279    2.377378
//    homeorder |   1.178831   .0647574     2.99   0.003     1.058502    1.312838
//              |
//         rucc |
//           2  |   .9996397   .0605664    -0.01   0.995     .8877092    1.125683
//           3  |   .9274107   .0594506    -1.18   0.240     .8179124    1.051568
//           4  |    .929086    .069041    -0.99   0.322      .803161    1.074754
//           5  |   1.158882   .1083134     1.58   0.115     .9649006     1.39186
//           6  |   1.015997   .0573863     0.28   0.779     .9095238    1.134934
//           7  |   .9716492    .060789    -0.46   0.646     .8595201    1.098406
//           8  |   .9263557   .0837969    -0.85   0.398     .7758527    1.106054
//           9  |   .8169737   .0798035    -2.07   0.039      .674623    .9893615
// ------------------------------------------------------------------------------
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// Compare to tabular data:
//
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(overcr~g)  mean(overcr~g)   sem(overcr~g)
// ----------+-----------------------------------------------
//         1 |            424       2.6526635        .1073744
//         2 |            424       2.5701786        .0845259
//         3 |            423       2.4333827         .084853
//         4 |            421       2.3884393        .0984617
//         5 |            429       2.3539667        .0906707
// ----------------------------------------------------------
// ----- PERCENT DIFFERENCE MODEL -----
// note: levels5 omitted because of collinearity
// note: overcrowding has noninteger values
//
// Iteration 0:   log likelihood = -3951.1381
// Iteration 1:   log likelihood = -3940.7532
// Iteration 2:   log likelihood = -3940.7418
// Iteration 3:   log likelihood = -3940.7418
//
// Generalized linear models                         Number of obs   =      2,121
// Optimization     : ML                             Residual df     =      2,107
//                                                   Scale parameter =          1
// Deviance         =   2305.28486                   (1/df) Deviance =   1.094108
// Pearson          =  3075.591558                   (1/df) Pearson  =   1.459702
//
// Variance function: V(u) = u                       [Poisson]
// Link function    : g(u) = ln(u)                   [Log]
//
//                                                   AIC             =    3.72913
// Log likelihood   = -3940.741843                   BIC             =  -13833.58
//
// ------------------------------------------------------------------------------
//              |                 OIM
// overcrowding |        IRR   Std. Err.      z    P>|z|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      levels1 |   1.160819   .0639501     2.71   0.007     1.042008    1.293176
//      levels2 |   1.105484   .0602608     1.84   0.066     .9934653    1.230133
//      levels3 |   1.045351   .0569059     0.81   0.415     .9395611    1.163052
//      levels4 |     1.0224   .0556318     0.41   0.684     .9189762    1.137462
//      levels5 |          1  (omitted)
//    homeorder |   1.178831   .0647574     2.99   0.003     1.058502    1.312838
//              |
//         rucc |
//           2  |   .9996397   .0605664    -0.01   0.995     .8877092    1.125683
//           3  |   .9274107   .0594506    -1.18   0.240     .8179124    1.051568
//           4  |    .929086    .069041    -0.99   0.322      .803161    1.074754
//           5  |   1.158882   .1083134     1.58   0.115     .9649006     1.39186
//           6  |   1.015997   .0573863     0.28   0.779     .9095238    1.134934
//           7  |   .9716492    .060789    -0.46   0.646     .8595201    1.098406
//           8  |   .9263557   .0837969    -0.85   0.398     .7758527    1.106054
//           9  |   .8169737   .0798035    -2.07   0.039      .674623    .9893615
//              |
//        _cons |   2.055545   .1525507     9.71   0.000     1.777279    2.377378
// ------------------------------------------------------------------------------
// Note: _cons estimates baseline incidence rate.
// (Standard errors scaled using square root of Pearson X2-based dispersion.)
// This front-end cannot display the desired image type.

// %% [markdown]
// ---
//
// # Exploratory analyses

// %%
frame change default
foreach var of varlist drivealone_p {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (mean) `var', by(iso5)
                    la var `var' "% of Drivers"
                        line `var' iso5, note("Commuting Alone by Vehicle")  
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(drivea~p)  mean(drivea~p)   sem(drivea~p)
// ----------+-----------------------------------------------
//         1 |            424       81.681981        .2874318
//         2 |            424        82.13087        .2068506
//         3 |            423       81.290184        .2205027
//         4 |            421       80.287177         .228309
//         5 |            429       77.251702        .4397825
// ----------------------------------------------------------
// This front-end cannot display the desired image type.

// %% [markdown]
// ---

// %%
frame change default
foreach var of varlist rucc {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (median) `var', by(iso5)
                    la var `var' "Meidan RUCC"
                        line `var' iso5, note("Urban-Rural")   
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(rucc)  mean(rucc)   sem(rucc)
// ----------+-----------------------------------
//         1 |        424   5.4504719    .1067798
//         2 |        424   4.7334905    .1121764
//         3 |        423   4.3309693    .1175278
//         4 |        421   4.0261283    .1174878
//         5 |        429   3.5174825    .1227618
// ----------------------------------------------
// This front-end cannot display the desired image type.

// %%
frame change default
foreach var of varlist longcommute_p {
    table iso5, c(count `var' mean `var' sem `var')
        frame put `var' iso5, into(`var')
            frame change `var'
                collapse (mean) `var', by(iso5)
                    la var `var' "% of Solo Commuters Driving 30+ mins"
                        line `var' iso5, note("Long Solo Commute")     
                            frame change default
                                frame drop `var'
}
// Out:
// ----------------------------------------------------------
// Distancin |
// g: Lowest |
// (1) to    |
// Highest   |
// (5)       |    N(longco~p)  mean(longco~p)   sem(longco~p)
// ----------+-----------------------------------------------
//         1 |            424         28.7875        .5970748
//         2 |            424        30.99316         .604934
//         3 |            423       31.846336        .5958293
//         4 |            421        31.92114        .5854699
//         5 |            429       33.511888        .5608478
// ----------------------------------------------------------
// This front-end cannot display the desired image type.

// %% [markdown]
// ---
//
// # External validation with Google data

// %%
// COMPARE March 1 to April 11 in Google and DL data by county-day


// Import Descartes Labs
	clear
	import delimited "https://raw.githubusercontent.com/descarteslabs/DL-COVID-19/master/DL-us-mobility-daterow.csv", encoding(ISO-8859-9) stringcols(6) 

	* Drop state aggregates
		drop if admin2==""

	* Format date
		gen date2=date(date,"YMD")
			format date2 %td
				drop date
					rename date2 date
		
	* Note data start and end dates for graphs
		su date 
			local latest: disp %td r(max)
				di "`latest'"
			local earliest: disp %td r(min)
				di "`earliest'"
	
	* Rename variables for consistency
		rename admin1 state
		rename admin2 county

	* Create quintiles of DL mobility
	/*
	xtile temp = last3_index, nq(5)
		gen iso5=.
		 replace iso5=1 if temp==5
			replace iso5=2 if temp==4
				replace iso5=3 if temp==3
					replace iso5=4 if temp==2
						replace iso5=5 if temp==1
							order iso5, a(last3_index)
								la var iso5 "Distancing: Lowest (1) to Highest (5)"
									drop temp
		*/
	save dl_x_valid, replace
	



// Process Google app check-in data
clear
import delimited "/Users/nabarun/Documents/GitHub/covid/fips-google-mobility-daily-as-of-04-20-20.csv", stringcols(1) numericcols(5 6 8)  

	* Format date 				
		gen date=date(report_date, "YMD")
			format date %td
				order date, first
					drop report_date
	
	* Note data start and end dates for graphs
		su date 
			local latest: disp %td r(max)
				di "`latest'"
			local earliest: disp %td r(min)
				di "`earliest'"
	
	* Retain latest data
	*su googledate 
	*		local latest: disp %td r(max)
	*			di "Keeping only records in Google mobility scrape from `latest'"
	*				keep if googledate==r(max)
		
		
	save google_x_valid, replace
	

	merge 1:1 date fips using dl_x_valid
	
	tab _merge
		keep if _merge==3
			drop _merge country_code admin_level
			
	* Variable cleanup
	

	
	foreach var of varlist retail_and_recreation_percent_ch-residential_percent_change_from_ {
	
		capture confirm numeric variable `var'
		if !_rc {
		
		destring `var', replace force
		*replace `var' = regexr(`var', "NULL","")
		*encode `var', replace force
		}
	
	}
	destring retail_and_recreation_percent_ch grocery_and_pharmacy_percent_cha workplaces_percent_change_from_b, replace force

	*xtile dl10 = m50_index, n(10)

	*xtile retailrec = retail_and_recreation_percent_ch, n(10)
		*bysort date: egen corretail = corr(retailrec m50_index)
			*heatplot corretail retailrec dl10, hexagon
			
	*xtile work = workplaces_percent_change_from_b, n(10)
		*bysort date: egen workcor = corr(work m50_index)
			*heatplot workcor work dl10, hexagon
			
	*xtile grocery = grocery_and_pharmacy_percent_cha, n(10)
	*	bysort date: egen grocerycor = corr(grocery m50_index)
			*heatplot grocerycor grocery dl10, hexagon			
			
	*xtile home = residential_percent_change_from_, n(10)
	*	bysort date: egen homecor = corr(home m50_index)
			*heatplot homecor home dl10, hexagon	colors(lean) size(samples) rec
	
	save crossvalid, replace
	
	
	
		*heatplot samples retail_and_recreation_percent_ch m50_index if m50_index<200, ylabel(25(25)175, nogrid) backfill colors(magma, reverse) hexagon sizeprop recenter

	
	use crossvalid, clear
	
		rename retail_and_recreation_percent_ch retailrec
		rename grocery_and_pharmacy_percent_cha grocery
		rename workplaces_percent_change_from_b work
		rename residential_percent_change_from_ home
		rename parks_percent_change_from_baseli parks
			la var parks "Parks"
		rename transit_stations_percent_change_ transit
			la var transit "Transit"
		
		
		gen m50i = m50_index-100
			la var m50i "Re-centered at zero"
		
		correlate m50i retailrec grocery work home parks transit
        matrix C = r(C)
        heatplot C, values(format(%9.3f)) scheme(s1mono) legend(off) aspectratio(1) lower nodiagonal p(lalign(center))

		heatplot m50i work if m50i<200,  aspectratio(1) discrete color(black) p(lalign(center))
// Out:
// (9 vars, 133,285 obs)
//
// (2,600 observations deleted)
//
//
//
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//         date |    130,685    21999.49    14.43114      21975      22024
//
//
// 19apr2020
//
//
// 01mar2020
//
//
//
// file dl_x_valid.dta saved
//
//
// (8 vars, 152,039 obs)
//
//
//
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//         date |    152,039     21988.1    16.42271      21960      22016
//
//
// 11apr2020
//
//
// 15feb2020
//
// file google_x_valid.dta saved
//
//
//     Result                           # of obs.
//     -----------------------------------------
//     not matched                        69,868
//         from master                    45,611  (_merge==1)
//         from using                     24,257  (_merge==2)
//
//     matched                           106,428  (_merge==3)
//     -----------------------------------------
//
//
//                  _merge |      Freq.     Percent        Cum.
// ------------------------+-----------------------------------
//         master only (1) |     45,611       25.87       25.87
//          using only (2) |     24,257       13.76       39.63
//             matched (3) |    106,428       60.37      100.00
// ------------------------+-----------------------------------
//                   Total |    176,296      100.00
//
// (69,868 observations deleted)
//
//
// parks_percent_change_from_baseli already numeric; no replace
// transit_stations_percent_change_ already numeric; no replace
// residential_percent_change_from_ already numeric; no replace
//
// retail_and_recreation_percent_ch: contains nonnumeric characters; replaced as in
// > t
// (13341 missing values generated)
// grocery_and_pharmacy_percent_cha: contains nonnumeric characters; replaced as in
// > t
// (17023 missing values generated)
// workplaces_percent_change_from_b: contains nonnumeric characters; replaced as by
// > te
// (4776 missing values generated)
//
// file crossvalid.dta saved
//
//
//
//
//
//
//
//
//
//
//
//
// (obs=20,891)
//
//              |     m50i retail~c  grocery     work     home    parks  transit
// -------------+---------------------------------------------------------------
//         m50i |   1.0000
//    retailrec |   0.8853   1.0000
//      grocery |   0.7139   0.7586   1.0000
//         work |   0.8409   0.9074   0.6947   1.0000
//         home |  -0.8172  -0.8909  -0.6763  -0.9734   1.0000
//        parks |   0.2286   0.3275   0.2976   0.2522  -0.2897   1.0000
//      transit |   0.7735   0.8349   0.6689   0.8106  -0.8112   0.3485   1.0000
//
//
//
// class ColrSpace undefined
// (384 lines skipped)
// (error occurred while loading colorpalette.ado)
// r(3000);
// r(3000);
